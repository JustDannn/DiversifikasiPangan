# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from scipy.spatial.distance import cdist
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

# %%
soil_path = "/kaggle/input/diversifikasi/JenisTanahIndonesia/Jenis Tanah Indonesia.shp"
soil_gdf = gpd.read_file(soil_path)

print(f"\nShape: {soil_gdf.shape}")
print(f"CRS (Coordinate Reference System): {soil_gdf.crs}")
print(f"\nColumns ({len(soil_gdf.columns)}):")
for col in soil_gdf.columns:
    print(f"   - {col}: {soil_gdf[col].dtype}")
# Out:
# Shape: (1166, 15)
# CRS (Coordinate Reference System): EPSG:4326
#
# Columns (15):
#    - SNUM: int64
#    - FAOSOIL: object
#    - DOMSOI: object
#    - PHASE1: object
#    - PHASE2: object
#    - MISCLU1: object
#    - MISCLU2: object
#    - PERMAFROST: object
#    - CNTCODE: int64
#    - CNTNAME: object
#    - SQKM: float64
#    - COUNTRY: object
#    - Kode: object
#    - Sub_Group_: object
#    - geometry: geometry

# %%
soil_gdf.head()
# Out:
#    SNUM    FAOSOIL DOMSOI PHASE1 PHASE2 MISCLU1 MISCLU2 PERMAFROST  CNTCODE  \
# 0  3653  Ao82-2/3b     Ao   None   None       0       0          0      101
# 1  3653  Ao82-2/3b     Ao   None   None       0       0          0      101
# 2  3749   Jd9-2/3a     Jd   None   None       0       0          0      101
# 3  3784    Lc97-3b     Lc   None   None       0       0          0      101
# 4  3653  Ao82-2/3b     Ao   None   None       0       0          0      101
#
#   CNTNAME   SQKM    COUNTRY Kode         Sub_Group_  \
# 0      ID  145.0  INDONESIA   Ao    Orthic Acrisols
# 1      ID   73.0  INDONESIA   Ao    Orthic Acrisols
# 2      ID  695.0  INDONESIA   Jd  Dystric Fluvisols
# 3      ID  839.0  INDONESIA   Lc   Chromic Luvisols
# 4      ID  815.0  INDONESIA   Ao    Orthic Acrisols
#
#                                             geometry
# 0  POLYGON ((95.23526 5.82758, 95.21981 5.83665, ...
# 1  POLYGON ((94.96084 5.71674, 94.96598 5.73524, ...
# 2  POLYGON ((95.13234 5.54738, 95.13266 5.55406, ...
# 3  POLYGON ((95.38913 5.68413, 95.41445 5.65465, ...
# 4  POLYGON ((95.66745 5.61220, 95.73069 5.58059, ...

# %%
print(f"   Unique values: {soil_gdf['FAOSOIL'].nunique()}")
print(f"\n   Categories:")
for soil in sorted(soil_gdf['FAOSOIL'].unique()):
    count = (soil_gdf['FAOSOIL'] == soil).sum()
    area = soil_gdf[soil_gdf['FAOSOIL'] == soil]['SQKM'].sum()
    print(f"   {soil}: {count} polygons, {area:,.0f} km²")
# Out:
#    Unique values: 101
#
#    Categories:
#    Af11-2/3a: 12 polygons, 17,459 km²
#    Af55-3b: 13 polygons, 40,816 km²
#    Af56-2a: 1 polygons, 7,928 km²
#    Af57-2a: 13 polygons, 27,348 km²
#    Ag15-2/3a: 1 polygons, 973 km²
#    Ah25-2c: 12 polygons, 67,035 km²
#    Ah26-3c: 3 polygons, 7,453 km²
#    Ah27-2/3c: 7 polygons, 64,150 km²
#    Ao103-3ab: 5 polygons, 11,286 km²
#    Ao104-2/3c: 28 polygons, 222,341 km²
#    Ao105-2/3c: 5 polygons, 10,654 km²
#    Ao106-2/3b: 7 polygons, 9,358 km²
#    Ao70-2/3b: 41 polygons, 64,102 km²
#    Ao71-2/3c: 12 polygons, 5,858 km²
#    Ao82-2/3b: 20 polygons, 74,428 km²
#    Ao83-2/3c: 4 polygons, 8,968 km²
#    Ap25-2/3a: 2 polygons, 5,688 km²
#    Ap27-2a: 10 polygons, 15,308 km²
#    Bd58-2c: 16 polygons, 49,027 km²
#    Bd59-3c: 3 polygons, 9,522 km²
#    Bd62-2/3a: 11 polygons, 3,276 km²
#    Bd63-2/3b: 3 polygons, 5,176 km²
#    Be116-2c: 10 polygons, 8,647 km²
#    Bf13-2/3b: 4 polygons, 4,685 km²
#    Bg7-2/3a: 1 polygons, 426 km²
#    Bh17-2bc: 2 polygons, 22,079 km²
#    Bh21-2c: 3 polygons, 32,782 km²
#    Bh24-2c: 4 polygons, 34,304 km²
#    Bv17-3a: 2 polygons, 1,056 km²
#    E13-2c: 6 polygons, 14,663 km²
#    E18-3c: 28 polygons, 11,453 km²
#    E21-3ab: 53 polygons, 15,256 km²
#    Fh12-2/3c: 6 polygons, 4,237 km²
#    Fh13-2b: 2 polygons, 13,949 km²
#    Fh14-2/3c: 15 polygons, 50,481 km²
#    Fo101-2b: 25 polygons, 30,670 km²
#    Fr31-2/3b: 3 polygons, 3,929 km²
#    Fr32-2/3c: 6 polygons, 4,318 km²
#    Fx32-2ab: 21 polygons, 8,401 km²
#    Fx38-2c: 1 polygons, 2,579 km²
#    Gd28-3a: 2 polygons, 2,168 km²
#    Ge54-3a: 3 polygons, 800 km²
#    Gh20-3a: 43 polygons, 38,528 km²
#    Gh21-3a: 5 polygons, 7,596 km²
#    I-Ao-2/3c: 2 polygons, 6,119 km²
#    I-E-3bc: 11 polygons, 10,365 km²
#    I-Lc-3b: 9 polygons, 20,367 km²
#    I-Lk-3bc: 5 polygons, 7,384 km²
#    I-Lv-3b: 2 polygons, 4,973 km²
#    I-Od-U-1c: 10 polygons, 10,637 km²
#    Jd10-2/3a: 17 polygons, 20,368 km²
#    Jd11-1a: 3 polygons, 2,220 km²
#    Jd12-2/3a: 8 polygons, 23,470 km²
#    Jd9-2/3a: 88 polygons, 97,949 km²
#    Je62-2/3a: 49 polygons, 26,206 km²
#    Je63-2/3a: 8 polygons, 4,513 km²
#    Je70-3a: 3 polygons, 1,937 km²
#    Je84-3a: 3 polygons, 6,819 km²
#    Je85-3a: 8 polygons, 32,448 km²
#    Jt12-3a: 3 polygons, 1,998 km²
#    Lc78-3c: 39 polygons, 55,077 km²
#    Lc97-3b: 13 polygons, 14,582 km²
#    Lc98-3c: 10 polygons, 10,425 km²
#    Lo65-2/3b: 8 polygons, 7,407 km²
#    Lo66-2/3c: 8 polygons, 20,409 km²
#    Lo67-2/3c: 2 polygons, 3,356 km²
#    Lv5-3b: 8 polygons, 10,949 km²
#    Lv6-3b: 2 polygons, 851 km²
#    NO DATA: 2 polygons, 266 km²
#    Nd54-3b: 6 polygons, 4,103 km²
#    Nd64-3a: 2 polygons, 3,142 km²
#    Ne60-3b: 7 polygons, 5,505 km²
#    Nh10-3b: 2 polygons, 1,197 km²
#    Nh9-3a: 4 polygons, 2,351 km²
#    Od19-a: 43 polygons, 95,997 km²
#    Od20-a: 21 polygons, 24,336 km²
#    Oe10-a: 1 polygons, 152 km²
#    Oe11-a: 14 polygons, 64,688 km²
#    Oe12-a: 26 polygons, 23,645 km²
#    Oe9-a: 1 polygons, 1,126 km²
#    Pg4-1a: 13 polygons, 13,010 km²
#    Ph12-1b: 7 polygons, 19,588 km²
#    Po27-1a: 18 polygons, 14,225 km²
#    Qa17-1a: 7 polygons, 25,316 km²
#    Qc59-1ab: 16 polygons, 43,088 km²
#    Qf48-1b: 4 polygons, 4,959 km²
#    Rc46-1ab: 1 polygons, 1,424 km²
#    Rd10-1a: 2 polygons, 265 km²
#    Re62-1ab: 2 polygons, 591 km²
#    Re82-1bc: 6 polygons, 3,091 km²
#    Th17-2c: 34 polygons, 25,308 km²
#    Th18-2ab: 1 polygons, 944 km²
#    Tm23-2c: 24 polygons, 9,704 km²
#    To24-2c: 18 polygons, 16,122 km²
#    To25-2b: 10 polygons, 7,417 km²
#    Tv38-1bc: 31 polygons, 16,074 km²
#    Vc57-3ab: 4 polygons, 1,751 km²
#    Vp61-3a: 14 polygons, 8,358 km²
#    Vp62-3b: 9 polygons, 5,034 km²
#    Vp63-3ab: 3 polygons, 5,761 km²
#    WAT: 20 polygons, 4,167 km²

# %%
print("Dominant Soil Types (DOMSOI):")
print(f"Unique values: {soil_gdf['DOMSOI'].nunique()}")
domsoi_summary = soil_gdf.groupby('DOMSOI')['SQKM'].agg(['count', 'sum']).sort_values('sum', ascending=False)
domsoi_summary.columns = ['Count', 'Total_Area_km2']
print(domsoi_summary.head(15))
# Out:
# Dominant Soil Types (DOMSOI):
# Unique values: 48
#         Count  Total_Area_km2
# DOMSOI
# Ao        122        406995.0
# Jd        116        144007.0
# Ah         22        138638.0
# Od         64        120333.0
# Af         39         93551.0
# Oe         42         89611.0
# Bh          9         89165.0
# Lc         62         80084.0
# Je         71         71923.0
# Fh         23         68667.0
# Bd         33         67001.0
# I          39         59845.0
# Gh         48         46124.0
# Qc         16         43088.0
# E          87         41372.0

# %%
subgroup_summary = soil_gdf.groupby('Sub_Group_')['SQKM'].agg(['count', 'sum']).sort_values('sum', ascending=False)
subgroup_summary.columns = ['Polygon_Count', 'Total_Area_km2']
subgroup_summary['Percentage'] = (subgroup_summary['Total_Area_km2'] / subgroup_summary['Total_Area_km2'].sum() * 100).round(2)
print(subgroup_summary.head(20))
# Out:
#                    Polygon_Count  Total_Area_km2  Percentage
# Sub_Group_
# Orthic Acrisols              122        406995.0       21.53
# Dystric Fluvisols            116        144007.0        7.62
# Humic Acrisols                22        138638.0        7.33
# Dystric Histosols             64        120333.0        6.37
# Ferric Acrisols               39         93551.0        4.95
# Eutric Histosols              42         89611.0        4.74
# Humic Cambisols                9         89165.0        4.72
# Chromic Luvisols              62         80084.0        4.24
# Eutric Fluvisols              71         71923.0        3.80
# Humic Ferralsols              23         68667.0        3.63
# Dystric Cambisols             33         67001.0        3.54
# LITHOSOLS                     39         59845.0        3.17
# Humic Gleysols                48         46124.0        2.44
# Cambic Arenosols              16         43088.0        2.28
# RENDZINAS                     87         41372.0        2.19
# Orthic Luvisols               18         31172.0        1.65
# Orthic Ferralsols             25         30670.0        1.62
# Humic Andosols                35         26252.0        1.39
# Albic Arenosols                7         25316.0        1.34
# Ochric Andosols               27         23537.0        1.24

# %%
fig, axes = plt.subplots(figsize=(16, 6))
# Bar chart of top soil types by area
top_soils = subgroup_summary.head(12)
bars = axes.barh(range(len(top_soils)), top_soils['Total_Area_km2'], color=plt.cm.viridis(np.linspace(0, 1, len(top_soils))))
axes.set_yticks(range(len(top_soils)))
axes.set_yticklabels(top_soils.index, fontsize=9)
axes.set_xlabel('Total Area (km^2)')
axes.set_title('Top 12 Soil Types by Area in Indonesia', fontweight='bold')
axes.invert_yaxis()

for i, (area, pct) in enumerate(zip(top_soils['Total_Area_km2'], top_soils['Percentage'])):
    axes.text(area + 5000, i, f'{pct}%', va='center', fontsize=8)
    
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(16, 6))
# Aggregate by major soil group
soil_gdf['Major_Group'] = soil_gdf['DOMSOI'].str.extract(r'^([A-Z][a-z]?)')
major_groups = soil_gdf.groupby('Major_Group')['SQKM'].sum().sort_values(ascending=False).head(8)
colors = plt.cm.Set3(np.linspace(0, 1, len(major_groups)))
wedges, texts, autotexts = axes.pie(major_groups.values, labels=major_groups.index, autopct='%1.1f%%', 
                                    colors=colors, startangle=90)
axes.set_title('Distribution by Major Soil Groups (FAO)', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# Load Elevation Data (Spot Height)
elevation_50k_path = "/kaggle/input/diversifikasi/SpotHeightIndonesia/Spot Height 50K.shp"
elevation_250k_path = "/kaggle/input/diversifikasi/SpotHeightIndonesia/Spot Height 250K.shp"

# Load both datasets
elevation_50k = gpd.read_file(elevation_50k_path)
elevation_250k = gpd.read_file(elevation_250k_path)

# %%
print("\nSpot Height 50K:")
print(f"   Shape: {elevation_50k.shape}")
print(f"   CRS: {elevation_50k.crs}")
print(f"   Columns: {list(elevation_50k.columns)}")
# Out:
# Spot Height 50K:
#    Shape: (3832212, 8)
#    CRS: EPSG:3857
#    Columns: ['OBJECTID', 'NAMOBJ', 'FCODE', 'ELEVAS', 'REMARK', 'SRS_ID', 'GLOBALID', 'geometry']

# %%
print("\nSample from 50K:")
display(elevation_50k.head(3))
# Out:
# Sample from 50K:
#     OBJECTID NAMOBJ  FCODE  ELEVAS REMARK SRS_ID  \
# 0  2682897.0     32  30104    32.0   None   None
# 1  2682898.0     44  30104    44.0   None   None
# 2  2682899.0     24  30104    24.0   None   None
#
#                                  GLOBALID                          geometry
# 0  {634D0812-C1D6-446D-A3D1-FB2C0997C871}  POINT (13310112.069 -571663.242)
# 1  {12505728-3D16-4B05-A6F5-669EA9136EF4}  POINT (13310655.501 -573194.397)
# 2  {F4B6FBD6-2266-4475-B54C-614383ED2E9B}  POINT (13310932.013 -575761.046)

# %%
print("\nSpot Height 250K:")
print(f"   Shape: {elevation_250k.shape}")
print(f"   CRS: {elevation_250k.crs}")
print(f"   Columns: {list(elevation_250k.columns)}")
# Out:
# Spot Height 250K:
#    Shape: (79865, 8)
#    CRS: EPSG:4326
#    Columns: ['OBJECTID', 'NAMOBJ', 'FCODE', 'ELEVAS', 'REMARK', 'SRS_ID', 'GLOBALID', 'geometry']

# %%
print("\nSample from 250K:")
display(elevation_250k.head(3))
# Out:
# Sample from 250K:
#    OBJECTID NAMOBJ  FCODE  ELEVAS       REMARK SRS_ID  \
# 0    1144.0   None  30104   241.0  Spot Height   None
# 1    1145.0   None  30104   353.0  Spot Height   None
# 2    1146.0   None  30104   262.0  Spot Height   None
#
#                                  GLOBALID                   geometry
# 0  {BA71667B-70F1-4E44-A9DE-C96BC665A6FD}  POINT (100.66707 0.43606)
# 1  {531EE78B-7FEA-4DE7-A1BE-CB4CB2C79528}  POINT (100.64720 0.45697)
# 2  {0C6947E4-2B04-473B-B87B-AB5219A4CB1E}  POINT (100.63295 0.47306)

# %%
elevation = elevation_250k.copy()

elevation = elevation.dropna(subset=['ELEVAS'])
elevation['ELEVAS'] = pd.to_numeric(elevation['ELEVAS'], errors='coerce')
elevation = elevation[elevation['ELEVAS'] >= 0]  # Remove negative values

print(f"\n Valid elevation points: {len(elevation):,}")
print(f"\n Elevation Statistics:")
print(f"   Min: {elevation['ELEVAS'].min():.0f} m")
print(f"   Max: {elevation['ELEVAS'].max():.0f} m")
print(f"   Mean: {elevation['ELEVAS'].mean():.1f} m")
print(f"   Median: {elevation['ELEVAS'].median():.1f} m")
print(f"   Std Dev: {elevation['ELEVAS'].std():.1f} m")
# Out:
#  Valid elevation points: 79,865
#
#  Elevation Statistics:
#    Min: 0 m
#    Max: 4767 m
#    Mean: 552.7 m
#    Median: 299.0 m
#    Std Dev: 686.7 m

# %%
# Categorize elevation
def categorize_elevation(elev):
    if elev < 100:
        return 'Coastal/Lowland (0-100m)'
    elif elev < 500:
        return 'Low Hills (100-500m)'
    elif elev < 1000:
        return 'Mid Elevation (500-1000m)'
    elif elev < 1500:
        return 'Highland (1000-1500m)'
    else:
        return 'Mountainous (>1500m)'

elevation['Elevation_Category'] = elevation['ELEVAS'].apply(categorize_elevation)

print("\nDistribution by Elevation Category:")
elev_dist = elevation['Elevation_Category'].value_counts()
for cat, count in elev_dist.items():
    print(f"   {cat}: {count:,} points ({count/len(elevation)*100:.1f}%)")
# Out:
# Distribution by Elevation Category:
#    Coastal/Lowland (0-100m): 28,060 points (35.1%)
#    Low Hills (100-500m): 20,672 points (25.9%)
#    Mid Elevation (500-1000m): 15,411 points (19.3%)
#    Highland (1000-1500m): 8,507 points (10.7%)
#    Mountainous (>1500m): 7,215 points (9.0%)

# %%
# Visualize Elevation Distribution
fig, axes = plt.subplots(figsize=(14, 5))

# Histogram
axes.hist(elevation['ELEVAS'], bins=50, color='steelblue', edgecolor='white', alpha=0.8)
axes.axvline(elevation['ELEVAS'].mean(), color='red', linestyle='--', linewidth=2, label=f"Mean: {elevation['ELEVAS'].mean():.0f}m")
axes.axvline(elevation['ELEVAS'].median(), color='orange', linestyle='--', linewidth=2, label=f"Median: {elevation['ELEVAS'].median():.0f}m")
axes.set_xlabel('Elevation (m)')
axes.set_ylabel('Frequency')
axes.set_title('Distribution of Spot Heights in Indonesia', fontweight='bold')
axes.legend()

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(14, 5))
# Bar chart by category
elev_order = ['Coastal/Lowland (0-100m)', 'Low Hills (100-500m)', 'Mid Elevation (500-1000m)', 
              'Highland (1000-1500m)', 'Mountainous (>1500m)']
elev_counts = [elev_dist.get(cat, 0) for cat in elev_order]
colors = ['#2ecc71', '#f1c40f', '#e67e22', '#e74c3c', '#9b59b6']
bars = axes.bar(range(len(elev_order)), elev_counts, color=colors)
axes.set_xticks(range(len(elev_order)))
axes.set_xticklabels(['Coastal\n(0-100m)', 'Low Hills\n(100-500m)', 'Mid\n(500-1000m)', 
                     'Highland\n(1000-1500m)', 'Mountain\n(>1500m)'], fontsize=9)
axes.set_ylabel('Number of Points')
axes.set_title('Elevation Categories Distribution', fontweight='bold')

for i, (count, bar) in enumerate(zip(elev_counts, bars)):
    axes.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 500, f'{count/len(elevation)*100:.1f}%', 
             ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
# Load Rainfall Data
rainfall_path = "/kaggle/input/diversifikasi/Jumlah Curah Hujan dan Jumlah Hari Hujan di Stasiun Pengamatan   BMKG 2011-2015.csv"
rainfall_raw = pd.read_csv(rainfall_path, header=3, encoding='utf-8')

# %%
rainfall_raw.shape
# Out:
# (140, 13)

# %%
rainfall_raw.columns
# Out:
# Index(['Provinsi', 'Stasiun BMKG', 'Jumlah Curah Hujan (mm)',
#        'Jumlah Hari Hujan (hari)', 'Jumlah Curah Hujan (mm).1',
#        'Jumlah Hari Hujan (hari).1', 'Jumlah Curah Hujan (mm).2',
#        'Jumlah Hari Hujan (hari).2', 'Jumlah Curah Hujan (mm).3',
#        'Jumlah Hari Hujan (hari).3', 'Jumlah Curah Hujan (mm).4',
#        'Jumlah Hari Hujan (hari).4', 'Unnamed: 12'],
#       dtype='object')

# %%
rainfall_raw.head(10)
# Out:
#                     Provinsi            Stasiun BMKG Jumlah Curah Hujan (mm)  \
# 0                       Aceh    Sultan Iskandar Muda                1 268.00
# 1             Sumatera Utara              Kualanamu1                2 042.00
# 2             Sumatera Barat                Sicincin                     NaN
# 3                       Riau  Sultan Syarif Kasim II                2 405.00
# 4                      Jambi           Sultan Thaha2                2 295.00
# 5           Sumatera Selatan                  Kenten                2 593.00
# 6                   Bengkulu              Pulau Baai                     NaN
# 7                    Lampung          Radin Inten II                1 568.00
# 8  Kepulauan Bangka Belitung             Depati Amir                2 921.00
# 9             Kepulauan Riau                  Kijang                3 893.00
#
#    Jumlah Hari Hujan (hari) Jumlah Curah Hujan (mm).1  \
# 0                     150.0                  1 098.00
# 1                     225.0                  3 175.00
# 2                       NaN                  4 339.00
# 3                     211.0                  2 636.00
# 4                     209.0                  1 874.00
# 5                     217.0                  3 083.00
# 6                       NaN                  2 545.00
# 7                     118.0                  1 685.00
# 8                     213.0                  2 018.00
# 9                     205.0                  3 253.00
#
#    Jumlah Hari Hujan (hari).1 Jumlah Curah Hujan (mm).2  \
# 0                       137.0                  1 623.60
# 1                       227.0                  2 627.00
# 2                       230.0                  4 627.40
# 3                       217.0                  2 628.70
# 4                       191.0                  2 093.60
# 5                       194.0                  3 409.20
# 6                       143.0                  3 980.90
# 7                       143.0                  2 456.70
# 8                       195.0                  2 839.20
# 9                       202.0                  3 389.40
#
#    Jumlah Hari Hujan (hari).2 Jumlah Curah Hujan (mm).3  \
# 0                       151.0                  2 264.40
# 1                       218.0                  2 148.00
# 2                       232.0                  2 838.40
# 3                       214.0                  2 343.70
# 4                       229.0                  1 781.00
# 5                       238.0                  1 668.30
# 6                       250.0                  3 323.00
# 7                       198.0                  1 682.50
# 8                       243.0                  1 675.00
# 9                       227.0                  3 064.00
#
#    Jumlah Hari Hujan (hari).3 Jumlah Curah Hujan (mm).4  \
# 0                       142.0                  1 575.00
# 1                       200.0                    975.90
# 2                       163.0                  3 548.00
# 3                       188.0                  2 048.30
# 4                       199.0                  1 694.90
# 5                       176.0                  1 947.20
# 6                       174.0                  2 668.90
# 7                       178.0                  1 628.10
# 8                       179.0                  1 534.70
# 9                       174.0                  2 250.90
#
#    Jumlah Hari Hujan (hari).4  Unnamed: 12
# 0                       146.0          NaN
# 1                       105.0          NaN
# 2                       185.0          NaN
# 3                       140.0          NaN
# 4                       135.0          NaN
# 5                       138.0          NaN
# 6                       166.0          NaN
# 7                       151.0          NaN
# 8                       163.0          NaN
# 9                       174.0          NaN

# %%
# Rename columns
rainfall = rainfall_raw.iloc[:34].copy()  # Only first 34 rows contain actual data
rainfall = rainfall.dropna(subset=['Provinsi'])
rainfall.columns = ['Provinsi', 'Stasiun_BMKG', 
                    'CH_2011', 'HH_2011', 
                    'CH_2012', 'HH_2012',
                    'CH_2013', 'HH_2013',
                    'CH_2014', 'HH_2014',
                    'CH_2015', 'HH_2015',
                    'Extra']

# %%
# Drop extra column and clean
rainfall = rainfall.drop('Extra', axis=1)

# %%
# Convert numeric columns
def clean_numeric(x):
    if pd.isna(x):
        return np.nan
    if isinstance(x, str):
        # Remove spaces used as thousand separators
        x = x.replace(' ', '').replace(',', '.')
    try:
        return float(x)
    except:
        return np.nan

numeric_cols = ['CH_2011', 'HH_2011', 'CH_2012', 'HH_2012', 'CH_2013', 'HH_2013',
                'CH_2014', 'HH_2014', 'CH_2015', 'HH_2015']

for col in numeric_cols:
    rainfall[col] = rainfall[col].apply(clean_numeric)

# %%
rainfall.shape
# Out:
# (34, 12)

# %%
rainfall['Provinsi'].nunique()
# Out:
# 34

# %%
rainfall.head(10)
# Out:
#                     Provinsi            Stasiun_BMKG  CH_2011  HH_2011  \
# 0                       Aceh    Sultan Iskandar Muda   1268.0    150.0
# 1             Sumatera Utara              Kualanamu1   2042.0    225.0
# 2             Sumatera Barat                Sicincin      NaN      NaN
# 3                       Riau  Sultan Syarif Kasim II   2405.0    211.0
# 4                      Jambi           Sultan Thaha2   2295.0    209.0
# 5           Sumatera Selatan                  Kenten   2593.0    217.0
# 6                   Bengkulu              Pulau Baai      NaN      NaN
# 7                    Lampung          Radin Inten II   1568.0    118.0
# 8  Kepulauan Bangka Belitung             Depati Amir   2921.0    213.0
# 9             Kepulauan Riau                  Kijang   3893.0    205.0
#
#    CH_2012  HH_2012  CH_2013  HH_2013  CH_2014  HH_2014  CH_2015  HH_2015
# 0   1098.0    137.0   1623.6    151.0   2264.4    142.0   1575.0    146.0
# 1   3175.0    227.0   2627.0    218.0   2148.0    200.0    975.9    105.0
# 2   4339.0    230.0   4627.4    232.0   2838.4    163.0   3548.0    185.0
# 3   2636.0    217.0   2628.7    214.0   2343.7    188.0   2048.3    140.0
# 4   1874.0    191.0   2093.6    229.0   1781.0    199.0   1694.9    135.0
# 5   3083.0    194.0   3409.2    238.0   1668.3    176.0   1947.2    138.0
# 6   2545.0    143.0   3980.9    250.0   3323.0    174.0   2668.9    166.0
# 7   1685.0    143.0   2456.7    198.0   1682.5    178.0   1628.1    151.0
# 8   2018.0    195.0   2839.2    243.0   1675.0    179.0   1534.7    163.0
# 9   3253.0    202.0   3389.4    227.0   3064.0    174.0   2250.9    174.0

# %%
# Calculate aggregated rainfall features per province
rainfall['Mean_Annual_Rainfall'] = rainfall[['CH_2011', 'CH_2012', 'CH_2013', 'CH_2014', 'CH_2015']].mean(axis=1)
rainfall['Mean_Rainy_Days'] = rainfall[['HH_2011', 'HH_2012', 'HH_2013', 'HH_2014', 'HH_2015']].mean(axis=1)
rainfall['Rainfall_Variability'] = rainfall[['CH_2011', 'CH_2012', 'CH_2013', 'CH_2014', 'CH_2015']].std(axis=1)
rainfall['CV_Rainfall'] = (rainfall['Rainfall_Variability'] / rainfall['Mean_Annual_Rainfall'] * 100).round(2)  # Coefficient of Variation

# Calculate rainfall intensity (mm per rainy day)
rainfall['Rainfall_Intensity'] = (rainfall['Mean_Annual_Rainfall'] / rainfall['Mean_Rainy_Days']).round(2)

# Categorize rainfall
def categorize_rainfall(rain):
    if pd.isna(rain):
        return 'Unknown'
    elif rain < 1500:
        return 'Dry (<1500mm)'
    elif rain < 2500:
        return 'Moderate (1500-2500mm)'
    elif rain < 3500:
        return 'Wet (2500-3500mm)'
    else:
        return 'Very Wet (>3500mm)'

rainfall['Rainfall_Category'] = rainfall['Mean_Annual_Rainfall'].apply(categorize_rainfall)

# %%
rainfall_summary = rainfall[['Provinsi', 'Stasiun_BMKG', 'Mean_Annual_Rainfall', 'Mean_Rainy_Days', 
                              'Rainfall_Variability', 'CV_Rainfall', 'Rainfall_Intensity', 'Rainfall_Category']].copy()
rainfall_summary = rainfall_summary.sort_values('Mean_Annual_Rainfall', ascending=False)

# %%
print(f"Rainfall Statistics:")
print(f"   Min: {rainfall['Mean_Annual_Rainfall'].min():.0f} mm/year")
print(f"   Max: {rainfall['Mean_Annual_Rainfall'].max():.0f} mm/year")
print(f"   Mean: {rainfall['Mean_Annual_Rainfall'].mean():.0f} mm/year")
# Out:
# Rainfall Statistics:
#    Min: 700 mm/year
#    Max: 3838 mm/year
#    Mean: 2318 mm/year

# %%
print(f"Rainfall Categories:")
for cat, count in rainfall['Rainfall_Category'].value_counts().items():
    print(f"   {cat}: {count} provinces")
# Out:
# Rainfall Categories:
#    Moderate (1500-2500mm): 19 provinces
#    Wet (2500-3500mm): 12 provinces
#    Dry (<1500mm): 2 provinces
#    Very Wet (>3500mm): 1 provinces

# %%
rainfall_summary
# Out:
#                      Provinsi            Stasiun_BMKG  Mean_Annual_Rainfall  \
# 2              Sumatera Barat                Sicincin              3838.200
# 30                     Maluku               Pattimura              3402.300
# 26           Sulawesi Selatan                  Maros4              3210.400
# 9              Kepulauan Riau                  Kijang              3170.060
# 6                    Bengkulu              Pulau Baai              3129.450
# 19           Kalimantan Barat                 Supadio              3020.960
# 32                Papua Barat                 Rendani              3011.860
# 20          Kalimantan Tengah            Tjilik Riwut              2978.480
# 24             Sulawesi Utara                Kayuwatu              2881.160
# 23           Kalimantan Utara         Tanjung Harapan              2706.700
# 21         Kalimantan Selatan              Banjarbaru              2624.720
# 22           Kalimantan Timur               Temindung              2551.360
# 5            Sumatera Selatan                  Kenten              2540.140
# 33                      Papua             Angkasapura              2434.380
# 3                        Riau  Sultan Syarif Kasim II              2412.340
# 11                 Jawa Barat                 Bandung              2313.660
# 12                Jawa Tengah                Semarang              2200.740
# 8   Kepulauan Bangka Belitung             Depati Amir              2197.580
# 1              Sumatera Utara              Kualanamu1              2193.580
# 13              DI Yogyakarta              Yogyakarta              2135.880
# 31               Maluku Utara         Sultan Babullah              2099.850
# 10                DKI Jakarta              Kemayoran3              2089.220
# 27          Sulawesi Tenggara                 Kendari              1995.750
# 4                       Jambi           Sultan Thaha2              1947.700
# 14                 Jawa Timur                  Juanda              1890.780
# 7                     Lampung          Radin Inten II              1804.060
# 15                     Banten                  Serang              1748.420
# 17        Nusa Tenggara Barat     Bandara Int. Lombok              1736.925
# 16                       Bali              Ngurah Rai              1733.700
# 28                  Gorontalo             Djalaluddin              1619.380
# 18        Nusa Tenggara Timur                 Lasiana              1576.120
# 0                        Aceh    Sultan Iskandar Muda              1565.800
# 29             Sulawesi Barat                  Majene              1338.780
# 25            Sulawesi Tengah   Mutiara SIS Al-Jufrie               699.740
#
#     Mean_Rainy_Days  Rainfall_Variability  CV_Rainfall  Rainfall_Intensity  \
# 2        202.500000            807.765098        21.05               18.95
# 30       219.750000           1376.693706        40.46               15.48
# 26       185.000000            594.286799        18.51               17.35
# 9        196.400000            598.693401        18.89               16.14
# 6        183.250000            662.348551        21.17               17.08
# 19       211.500000            267.214657         8.85               14.28
# 32       240.400000            322.380533        10.70               12.53
# 20       199.800000            354.177084        11.89               14.91
# 24       225.400000            689.039424        23.92               12.78
# 23       222.333333            423.659498        15.65               12.17
# 21       210.000000            254.062378         9.68               12.50
# 22       210.600000            370.807299        14.53               12.11
# 5        192.600000            735.601671        28.96               13.19
# 33       207.200000           1039.357360        42.69               11.75
# 3        194.000000            241.932786        10.03               12.43
# 11       215.400000            342.087895        14.79               10.74
# 12       170.400000            449.249027        20.41               12.92
# 8        198.600000            648.028056        29.49               11.07
# 1        195.000000            815.296990        37.17               11.25
# 13       152.200000            147.755024         6.92               14.03
# 31       191.000000            932.801063        44.42               10.99
# 10       147.250000            670.927412        32.11               14.19
# 27       160.000000            535.373798        26.83               12.47
# 4        192.600000            244.454761        12.55               10.11
# 14       156.000000            328.511068        17.37               12.12
# 7        157.600000            367.959689        20.40               11.45
# 15       174.600000           1030.286311        58.93               10.01
# 17       127.500000            471.866509        27.17               13.62
# 16       149.400000            382.050180        22.04               11.60
# 28       171.400000            519.922814        32.11                9.45
# 18       107.800000            364.455446        23.12               14.62
# 0        145.200000            446.930957        28.54               10.78
# 29       156.800000            305.068455        22.79                8.54
# 25       117.500000            161.397004        23.07                5.96
#
#          Rainfall_Category
# 2       Very Wet (>3500mm)
# 30       Wet (2500-3500mm)
# 26       Wet (2500-3500mm)
# 9        Wet (2500-3500mm)
# 6        Wet (2500-3500mm)
# 19       Wet (2500-3500mm)
# 32       Wet (2500-3500mm)
# 20       Wet (2500-3500mm)
# 24       Wet (2500-3500mm)
# 23       Wet (2500-3500mm)
# 21       Wet (2500-3500mm)
# 22       Wet (2500-3500mm)
# 5        Wet (2500-3500mm)
# 33  Moderate (1500-2500mm)
# 3   Moderate (1500-2500mm)
# 11  Moderate (1500-2500mm)
# 12  Moderate (1500-2500mm)
# 8   Moderate (1500-2500mm)
# 1   Moderate (1500-2500mm)
# 13  Moderate (1500-2500mm)
# 31  Moderate (1500-2500mm)
# 10  Moderate (1500-2500mm)
# 27  Moderate (1500-2500mm)
# 4   Moderate (1500-2500mm)
# 14  Moderate (1500-2500mm)
# 7   Moderate (1500-2500mm)
# 15  Moderate (1500-2500mm)
# 17  Moderate (1500-2500mm)
# 16  Moderate (1500-2500mm)
# 28  Moderate (1500-2500mm)
# 18  Moderate (1500-2500mm)
# 0   Moderate (1500-2500mm)
# 29           Dry (<1500mm)
# 25           Dry (<1500mm)

# %%
# Visualize Rainfall Data
fig, axes = plt.subplots(figsize=(14, 10))

#mean annual rainfall by province
sorted_rainfall = rainfall.sort_values('Mean_Annual_Rainfall', ascending=True)
colors = [plt.cm.Blues(0.3 + 0.7*x/sorted_rainfall['Mean_Annual_Rainfall'].max()) for x in sorted_rainfall['Mean_Annual_Rainfall']]
axes.barh(range(len(sorted_rainfall)), sorted_rainfall['Mean_Annual_Rainfall'], color=colors)
axes.set_yticks(range(len(sorted_rainfall)))
axes.set_yticklabels(sorted_rainfall['Provinsi'], fontsize=7)
axes.set_xlabel('Mean Annual Rainfall (mm)')
axes.set_title('Mean Annual Rainfall by Province (2011-2015)', fontweight='bold')
axes.axvline(rainfall['Mean_Annual_Rainfall'].mean(), color='red', linestyle='--', linewidth=1.5, 
            label=f"National Mean: {rainfall['Mean_Annual_Rainfall'].mean():.0f}mm")
axes.legend(fontsize=8)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(14, 10))

# Rainfall variability vs mean rainfall
scatter = axes.scatter(rainfall['Mean_Annual_Rainfall'], rainfall['Rainfall_Variability'], 
                       c=rainfall['Mean_Rainy_Days'], cmap='YlGnBu', s=80, alpha=0.7, edgecolors='black')
axes.set_xlabel('Mean Annual Rainfall (mm)')
axes.set_ylabel('Rainfall Variability (Std Dev)')
axes.set_title('Rainfall Variability vs Mean Rainfall', fontweight='bold')
plt.colorbar(scatter, ax=axes, label='Mean Rainy Days')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(14, 10))

# Distribution of rainfall categories
cat_counts = rainfall['Rainfall_Category'].value_counts()
colors_cat = ['#e74c3c', '#f39c12', '#3498db', '#2ecc71']
axes.pie(cat_counts.values, labels=cat_counts.index, autopct='%1.1f%%', colors=colors_cat, startangle=90)
axes.set_title('Distribution of Rainfall Categories', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(14, 10))

# Rainfall time series trends
years = [2011, 2012, 2013, 2014, 2015]
for idx, row in rainfall.sample(min(8, len(rainfall))).iterrows():
    values = [row['CH_2011'], row['CH_2012'], row['CH_2013'], row['CH_2014'], row['CH_2015']]
    axes.plot(years, values, marker='o', linewidth=1, alpha=0.7, label=row['Provinsi'][:15])
axes.set_xlabel('Year')
axes.set_ylabel('Annual Rainfall (mm)')
axes.set_title('Rainfall Trends (Sample Provinces)', fontweight='bold')
axes.legend(fontsize=7, loc='upper right')

plt.tight_layout()
plt.show()

# %%
soil_area = soil_gdf.groupby('Sub_Group_')['SQKM'].sum().sort_values(ascending=False)
len(soil_area)
# Out:
# 45

# %%
# For clustering, we'll group soil types into agroecologically meaningful categories
def classify_soil_agriculture(soil_type):
    """Classify soil types into agricultural categories"""
    soil_type = str(soil_type).upper()
    
    # Alluvial/Fluvisols - Good for irrigated crops (rice)
    if 'FLUVISOL' in soil_type or 'ALLUVIAL' in soil_type:
        return 'Alluvial'
    
    # Volcanic soils (Andosols) - Excellent fertility
    elif 'ANDOSOL' in soil_type or 'VOLCANIC' in soil_type:
        return 'Volcanic'
    
    # Organic soils (Histosols) - Peat, suitable for sago
    elif 'HISTOSOL' in soil_type or 'PEAT' in soil_type or 'ORGANIC' in soil_type:
        return 'Organic_Peat'
    
    # Lateritic/Weathered (Ferralsols, Acrisols) - Low fertility, need management
    elif 'FERRAL' in soil_type or 'ACRISOL' in soil_type or 'LATERIT' in soil_type:
        return 'Lateritic_Weathered'
    
    # Calcareous (Rendzinas, Luvisols) - Suitable for specific crops
    elif 'RENDZINA' in soil_type or 'LUVISOL' in soil_type or 'CALC' in soil_type:
        return 'Calcareous'
    
    # Sandy (Arenosols) - Well-drained, specific crops
    elif 'ARENOSOL' in soil_type or 'SANDY' in soil_type:
        return 'Sandy'
    
    # Clayey/Heavy (Vertisols, Gleysols) - Rice, flood-tolerant crops
    elif 'VERTISOL' in soil_type or 'GLEYSOL' in soil_type or 'CLAY' in soil_type:
        return 'Clayey_Hydromorphic'
    
    # Rocky/Shallow (Lithosols) - Limited agriculture
    elif 'LITHOSOL' in soil_type or 'ROCK' in soil_type:
        return 'Rocky_Shallow'
    
    # General Cambisols - Moderate fertility
    elif 'CAMBISOL' in soil_type:
        return 'Cambisol'
    
    else:
        return 'Other'

soil_gdf['Agri_Soil_Class'] = soil_gdf['Sub_Group_'].apply(classify_soil_agriculture)
agri_soil_summary = soil_gdf.groupby('Agri_Soil_Class')['SQKM'].sum().sort_values(ascending=False)

# %%
for soil_class, area in agri_soil_summary.items():
    pct = area / agri_soil_summary.sum() * 100
    print(f"   {soil_class}: {area:,.0f} km² ({pct:.1f}%)")
# Out:
#    Lateritic_Weathered: 789,361 km² (41.7%)
#    Alluvial: 217,928 km² (11.5%)
#    Organic_Peat: 209,944 km² (11.1%)
#    Cambisol: 166,295 km² (8.8%)
#    Calcareous: 165,852 km² (8.8%)
#    Volcanic: 75,569 km² (4.0%)
#    Clayey_Hydromorphic: 73,678 km² (3.9%)
#    Sandy: 68,404 km² (3.6%)
#    Other: 67,819 km² (3.6%)
#    Rocky_Shallow: 59,845 km² (3.2%)

# %%
# Visualize Agricultural Soil Classification
fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.Set3(np.linspace(0, 1, len(agri_soil_summary)))
bars = ax.barh(range(len(agri_soil_summary)), agri_soil_summary.values, color=colors)
ax.set_yticks(range(len(agri_soil_summary)))
ax.set_yticklabels(agri_soil_summary.index)
ax.set_xlabel('Area (km^2)')
ax.set_title('Indonesian Soils by Agricultural Classification', fontweight='bold', fontsize=12)
ax.invert_yaxis()

# Add percentage labels
for i, (v, pct) in enumerate(zip(agri_soil_summary.values, agri_soil_summary.values/agri_soil_summary.sum()*100)):
    ax.text(v + 10000, i, f'{pct:.1f}%', va='center', fontsize=9)

plt.tight_layout()
plt.show()

# %%
# Build the Feature Matrix for Clustering
features_df = rainfall[['Provinsi', 'Mean_Annual_Rainfall', 'Mean_Rainy_Days', 
                         'Rainfall_Variability', 'CV_Rainfall', 'Rainfall_Intensity']].copy()
features_df = features_df.reset_index(drop=True)

# %%
# Create derived climate indices
features_df['Aridity_Index'] = features_df['Mean_Annual_Rainfall'] / 2500  # Normalized to typical humid tropical

# Rainfall Seasonality Proxy
features_df['Seasonality_Index'] = features_df['CV_Rainfall'] / 100

# Wetness Duration (proxy for continuous wet conditions)
features_df['Wetness_Duration'] = features_df['Mean_Rainy_Days'] / 365

# %%
# Climate Zone Classification
def classify_climate_zone(row):
    rainfall = row['Mean_Annual_Rainfall']
    rainy_days = row['Mean_Rainy_Days']
    
    if pd.isna(rainfall) or pd.isna(rainy_days):
        return 'Unknown'
    elif rainfall >= 3000 and rainy_days >= 200:
        return 'Equatorial_Humid'
    elif rainfall >= 2000 and rainy_days >= 150:
        return 'Tropical_Wet'
    elif rainfall >= 1500 and rainy_days >= 120:
        return 'Tropical_Moist'
    elif rainfall >= 1000:
        return 'Tropical_Seasonal'
    else:
        return 'Semi_Arid'

features_df['Climate_Zone'] = features_df.apply(classify_climate_zone, axis=1)

# %%
# Regional Classification based on Indonesian geography
def classify_region(province):
    province = str(province).upper()
    
    # Sumatra
    if any(x in province for x in ['ACEH', 'SUMATERA', 'RIAU', 'JAMBI', 'BENGKULU', 'LAMPUNG', 'BANGKA']):
        return 'Sumatra'
    # Java-Bali
    elif any(x in province for x in ['JAKARTA', 'JAWA', 'BANTEN', 'YOGYAKARTA', 'BALI']):
        return 'Java_Bali'
    # Kalimantan
    elif 'KALIMANTAN' in province:
        return 'Kalimantan'
    # Sulawesi
    elif 'SULAWESI' in province or 'GORONTALO' in province:
        return 'Sulawesi'
    # Nusa Tenggara
    elif 'NUSA TENGGARA' in province:
        return 'Nusa_Tenggara'
    # Maluku & Papua
    elif any(x in province for x in ['MALUKU', 'PAPUA']):
        return 'Maluku_Papua'
    else:
        return 'Other'

features_df['Region'] = features_df['Provinsi'].apply(classify_region)

# %%
features_df.shape
# Out:
# (34, 11)

# %%
len(features_df)
# Out:
# 34

# %%
print(f"Features Created:")
for col in features_df.columns:
    print(f"   - {col}")
# Out:
# Features Created:
#    - Provinsi
#    - Mean_Annual_Rainfall
#    - Mean_Rainy_Days
#    - Rainfall_Variability
#    - CV_Rainfall
#    - Rainfall_Intensity
#    - Aridity_Index
#    - Seasonality_Index
#    - Wetness_Duration
#    - Climate_Zone
#    - Region

# %%
features_df.head(10)
# Out:
#                     Provinsi  Mean_Annual_Rainfall  Mean_Rainy_Days  \
# 0                       Aceh               1565.80           145.20
# 1             Sumatera Utara               2193.58           195.00
# 2             Sumatera Barat               3838.20           202.50
# 3                       Riau               2412.34           194.00
# 4                      Jambi               1947.70           192.60
# 5           Sumatera Selatan               2540.14           192.60
# 6                   Bengkulu               3129.45           183.25
# 7                    Lampung               1804.06           157.60
# 8  Kepulauan Bangka Belitung               2197.58           198.60
# 9             Kepulauan Riau               3170.06           196.40
#
#    Rainfall_Variability  CV_Rainfall  Rainfall_Intensity  Aridity_Index  \
# 0            446.930957        28.54               10.78       0.626320
# 1            815.296990        37.17               11.25       0.877432
# 2            807.765098        21.05               18.95       1.535280
# 3            241.932786        10.03               12.43       0.964936
# 4            244.454761        12.55               10.11       0.779080
# 5            735.601671        28.96               13.19       1.016056
# 6            662.348551        21.17               17.08       1.251780
# 7            367.959689        20.40               11.45       0.721624
# 8            648.028056        29.49               11.07       0.879032
# 9            598.693401        18.89               16.14       1.268024
#
#    Seasonality_Index  Wetness_Duration      Climate_Zone   Region
# 0             0.2854          0.397808    Tropical_Moist  Sumatra
# 1             0.3717          0.534247      Tropical_Wet  Sumatra
# 2             0.2105          0.554795  Equatorial_Humid  Sumatra
# 3             0.1003          0.531507      Tropical_Wet  Sumatra
# 4             0.1255          0.527671    Tropical_Moist  Sumatra
# 5             0.2896          0.527671      Tropical_Wet  Sumatra
# 6             0.2117          0.502055      Tropical_Wet  Sumatra
# 7             0.2040          0.431781    Tropical_Moist  Sumatra
# 8             0.2949          0.544110      Tropical_Wet  Sumatra
# 9             0.1889          0.538082      Tropical_Wet  Sumatra

# %%
# Add soil suitability indices based on regional characteristics
def get_soil_suitability(region, climate_zone):
    """Values represent relative suitability scores (0-1 scale)."""
    soil_scores = {
        'Alluvial': 0.5, 'Volcanic': 0.5, 'Organic_Peat': 0.5, 
        'Lateritic': 0.5, 'Calcareous': 0.5
    }
    
    if region == 'Sumatra':
        # Sumatra: High peat, good alluvial, some volcanic
        soil_scores = {'Alluvial': 0.7, 'Volcanic': 0.3, 'Organic_Peat': 0.8, 
                       'Lateritic': 0.6, 'Calcareous': 0.2}
    elif region == 'Java_Bali':
        # Java/Bali: Excellent volcanic, good alluvial
        soil_scores = {'Alluvial': 0.8, 'Volcanic': 0.9, 'Organic_Peat': 0.1, 
                       'Lateritic': 0.3, 'Calcareous': 0.4}
    elif region == 'Kalimantan':
        # Kalimantan: Dominant peat, lateritic
        soil_scores = {'Alluvial': 0.5, 'Volcanic': 0.1, 'Organic_Peat': 0.9, 
                       'Lateritic': 0.8, 'Calcareous': 0.1}
    elif region == 'Sulawesi':
        # Sulawesi: Mixed, calcareous in some areas
        soil_scores = {'Alluvial': 0.6, 'Volcanic': 0.4, 'Organic_Peat': 0.3, 
                       'Lateritic': 0.6, 'Calcareous': 0.7}
    elif region == 'Nusa_Tenggara':
        # Nusa Tenggara: Calcareous, volcanic, drier soils
        soil_scores = {'Alluvial': 0.4, 'Volcanic': 0.6, 'Organic_Peat': 0.05, 
                       'Lateritic': 0.4, 'Calcareous': 0.8}
    elif region == 'Maluku_Papua':
        # Maluku/Papua: High organic/peat in Papua, mixed in Maluku
        soil_scores = {'Alluvial': 0.6, 'Volcanic': 0.3, 'Organic_Peat': 0.7, 
                       'Lateritic': 0.7, 'Calcareous': 0.3}
    
    return soil_scores

# %%
# Apply soil indices
for idx, row in features_df.iterrows():
    scores = get_soil_suitability(row['Region'], row['Climate_Zone'])
    for soil_type, score in scores.items():
        features_df.loc[idx, f'Soil_{soil_type}'] = score

# Calculate composite soil quality index
features_df['Soil_Quality_Index'] = (
    features_df['Soil_Volcanic'] * 0.3 + 
    features_df['Soil_Alluvial'] * 0.25 + 
    features_df['Soil_Organic_Peat'] * 0.15 + 
    features_df['Soil_Calcareous'] * 0.15 +
    features_df['Soil_Lateritic'] * 0.15
)

print(features_df[['Provinsi', 'Region', 'Soil_Alluvial', 'Soil_Volcanic', 
                   'Soil_Organic_Peat', 'Soil_Quality_Index']].head(10))
# Out:
#                     Provinsi   Region  Soil_Alluvial  Soil_Volcanic  \
# 0                       Aceh  Sumatra            0.7            0.3
# 1             Sumatera Utara  Sumatra            0.7            0.3
# 2             Sumatera Barat  Sumatra            0.7            0.3
# 3                       Riau  Sumatra            0.7            0.3
# 4                      Jambi  Sumatra            0.7            0.3
# 5           Sumatera Selatan  Sumatra            0.7            0.3
# 6                   Bengkulu  Sumatra            0.7            0.3
# 7                    Lampung  Sumatra            0.7            0.3
# 8  Kepulauan Bangka Belitung  Sumatra            0.7            0.3
# 9             Kepulauan Riau  Sumatra            0.7            0.3
#
#    Soil_Organic_Peat  Soil_Quality_Index
# 0                0.8               0.505
# 1                0.8               0.505
# 2                0.8               0.505
# 3                0.8               0.505
# 4                0.8               0.505
# 5                0.8               0.505
# 6                0.8               0.505
# 7                0.8               0.505
# 8                0.8               0.505
# 9                0.8               0.505

# %%
# Select numeric features for clustering
numeric_features = [
    'Mean_Annual_Rainfall', 'Mean_Rainy_Days', 'Rainfall_Variability',
    'Aridity_Index', 'Seasonality_Index', 'Wetness_Duration',
    'Soil_Alluvial', 'Soil_Volcanic', 'Soil_Organic_Peat', 
    'Soil_Lateritic', 'Soil_Calcareous', 'Soil_Quality_Index'
]

# %%
X_raw = features_df[numeric_features].copy()

# %%
X_raw.isnull().sum()
# Out:
# Mean_Annual_Rainfall    0
# Mean_Rainy_Days         0
# Rainfall_Variability    0
# Aridity_Index           0
# Seasonality_Index       0
# Wetness_Duration        0
# Soil_Alluvial           0
# Soil_Volcanic           0
# Soil_Organic_Peat       0
# Soil_Lateritic          0
# Soil_Calcareous         0
# Soil_Quality_Index      0
# dtype: int64

# %%
X_raw = X_raw.fillna(X_raw.median())

# %%
X_raw.isnull().sum().sum()
# Out:
# 0

# %%
# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_raw)
X_scaled_df = pd.DataFrame(X_scaled, columns=numeric_features)

# %%
X_scaled_df.shape
# Out:
# (34, 12)

# %%
X_scaled_df.describe().round(2)
# Out:
#        Mean_Annual_Rainfall  Mean_Rainy_Days  Rainfall_Variability  \
# count                 34.00            34.00                 34.00
# mean                   0.00             0.00                 -0.00
# std                    1.02             1.02                  1.02
# min                   -2.45            -2.34                 -1.37
# 25%                   -0.75            -0.79                 -0.70
# 50%                   -0.18             0.31                 -0.28
# 75%                    0.79             0.76                  0.51
# max                    2.30             1.84                  3.08
#
#        Aridity_Index  Seasonality_Index  Wetness_Duration  Soil_Alluvial  \
# count          34.00              34.00             34.00          34.00
# mean           -0.00              -0.00             -0.00          -0.00
# std             1.02               1.02              1.02           1.02
# min            -2.45              -1.45             -2.34          -2.14
# 25%            -0.75              -0.74             -0.79          -0.39
# 50%            -0.18              -0.16              0.31           0.05
# 75%             0.79               0.47              0.76           0.49
# max             2.30               3.11              1.84           1.36
#
#        Soil_Volcanic  Soil_Organic_Peat  Soil_Lateritic  Soil_Calcareous  \
# count          34.00              34.00           34.00            34.00
# mean           -0.00               0.00            0.00            -0.00
# std             1.02               1.02            1.02             1.02
# min            -1.24              -1.46           -1.63            -1.17
# 25%            -0.49              -1.16           -0.72            -0.72
# 50%            -0.49               0.53            0.20            -0.28
# 75%             0.45               0.84            0.65             0.17
# max             1.77               1.15            1.42             1.96
#
#        Soil_Quality_Index
# count               34.00
# mean                -0.00
# std                  1.02
# min                 -1.66
# 25%                 -0.26
# 50%                 -0.06
# 75%                  0.04
# max                  1.63

# %%
province_names = features_df['Provinsi'].values

# %%
# Determine optimal number of clusters
k_range = range(2, 11)

# Store metrics
inertias = []
silhouettes = []
calinski_scores = []
davies_bouldin_scores = []

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10, max_iter=300)
    labels = kmeans.fit_predict(X_scaled)
    
    inertias.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(X_scaled, labels))
    calinski_scores.append(calinski_harabasz_score(X_scaled, labels))
    davies_bouldin_scores.append(davies_bouldin_score(X_scaled, labels))
    
    print(f"k={k}: Silhouette={silhouettes[-1]:.3f}, Calinski={calinski_scores[-1]:.1f}, Davies-Bouldin={davies_bouldin_scores[-1]:.3f}")
# Out:
# k=2: Silhouette=0.342, Calinski=21.8, Davies-Bouldin=1.177
# k=3: Silhouette=0.374, Calinski=19.4, Davies-Bouldin=0.999
# k=4: Silhouette=0.350, Calinski=19.5, Davies-Bouldin=1.067
# k=5: Silhouette=0.355, Calinski=19.0, Davies-Bouldin=1.057
# k=6: Silhouette=0.352, Calinski=17.4, Davies-Bouldin=1.044
# k=7: Silhouette=0.399, Calinski=17.7, Davies-Bouldin=0.903
# k=8: Silhouette=0.383, Calinski=18.6, Davies-Bouldin=0.849
# k=9: Silhouette=0.397, Calinski=18.9, Davies-Bouldin=0.705
# k=10: Silhouette=0.428, Calinski=19.7, Davies-Bouldin=0.672

# %%
# Visualize cluster evaluation metrics
fig, axes = plt.subplots(figsize=(14, 10))

# Elbow Method
axes.plot(k_range, inertias, 'bo-', linewidth=2, markersize=8)
axes.set_xlabel('Number of Clusters (k)')
axes.set_ylabel('Inertia (Within-cluster Sum of Squares)')
axes.set_title('Elbow Method', fontweight='bold')
axes.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(14, 10))

# Silhouette Score
axes.plot(k_range, silhouettes, 'go-', linewidth=2, markersize=8)
axes.set_xlabel('Number of Clusters (k)')
axes.set_ylabel('Silhouette Score')
axes.set_title('Silhouette Score (Higher is Better)', fontweight='bold')
axes.axhline(y=max(silhouettes), color='r', linestyle='--', alpha=0.5)
axes.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(14, 10))

# Calinski-Harabasz Index
axes.plot(k_range, calinski_scores, 'mo-', linewidth=2, markersize=8)
axes.set_xlabel('Number of Clusters (k)')
axes.set_ylabel('Calinski-Harabasz Index')
axes.set_title('Calinski-Harabasz Index (Higher is Better)', fontweight='bold')
axes.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(14, 10))

# Davies-Bouldin Index
axes.plot(k_range, davies_bouldin_scores, 'ro-', linewidth=2, markersize=8)
axes.set_xlabel('Number of Clusters (k)')
axes.set_ylabel('Davies-Bouldin Index')
axes.set_title('Davies-Bouldin Index (Lower is Better)', fontweight='bold')
axes.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Determine optimal k based on metrics
best_silhouette_k = k_range[np.argmax(silhouettes)]
best_calinski_k = k_range[np.argmax(calinski_scores)]
best_davies_k = k_range[np.argmin(davies_bouldin_scores)]

# %%
print(f"Best k by Silhouette Score: {best_silhouette_k} (score: {max(silhouettes):.3f})")
print(f"Best k by Calinski-Harabasz: {best_calinski_k} (score: {max(calinski_scores):.1f})")
print(f"Best k by Davies-Bouldin: {best_davies_k} (score: {min(davies_bouldin_scores):.3f})")
# Out:
# Best k by Silhouette Score: 10 (score: 0.428)
# Best k by Calinski-Harabasz: 2 (score: 21.8)
# Best k by Davies-Bouldin: 10 (score: 0.672)

# %%
OPTIMAL_K = 9

print(f"SELECTED: k = {OPTIMAL_K}")
# Out:
# SELECTED: k = 9

# %%
# Fit KMeans
kmeans = KMeans(n_clusters=OPTIMAL_K, random_state=42, n_init=20, max_iter=500)
kmeans_labels = kmeans.fit_predict(X_scaled)

# Add cluster labels to features dataframe
features_df['Cluster_KMeans'] = kmeans_labels

# %%
# Cluster statistics
for cluster in range(OPTIMAL_K):
    count = (kmeans_labels == cluster).sum()
    provinces = features_df[features_df['Cluster_KMeans'] == cluster]['Provinsi'].values
    print(f"\n   Cluster {cluster}: {count} provinces")
    print(f"   Provinces: {', '.join(provinces)}")
# Out:
#    Cluster 0: 1 provinces
#    Provinces: Banten
#
#    Cluster 1: 3 provinces
#    Provinces: Sumatera Barat, Bengkulu, Kepulauan Riau
#
#    Cluster 2: 6 provinces
#    Provinces: DKI Jakarta, Jawa Barat, Jawa Tengah, DI Yogyakarta, Jawa Timur, Bali
#
#    Cluster 3: 2 provinces
#    Provinces: Nusa Tenggara Barat, Nusa Tenggara Timur
#
#    Cluster 4: 6 provinces
#    Provinces: Kalimantan Barat, Kalimantan Tengah, Kalimantan Selatan, Kalimantan Timur, Kalimantan Utara, Papua Barat
#
#    Cluster 5: 4 provinces
#    Provinces: Sulawesi Tengah, Sulawesi Tenggara, Gorontalo, Sulawesi Barat
#
#    Cluster 6: 6 provinces
#    Provinces: Sumatera Utara, Sumatera Selatan, Kepulauan Bangka Belitung, Maluku, Maluku Utara, Papua
#
#    Cluster 7: 4 provinces
#    Provinces: Aceh, Riau, Jambi, Lampung
#
#    Cluster 8: 2 provinces
#    Provinces: Sulawesi Utara, Sulawesi Selatan

# %%
# Calculate cluster metrics
print(f"   Silhouette Score: {silhouette_score(X_scaled, kmeans_labels):.3f}")
print(f"   Calinski-Harabasz Index: {calinski_harabasz_score(X_scaled, kmeans_labels):.1f}")
print(f"   Davies-Bouldin Index: {davies_bouldin_score(X_scaled, kmeans_labels):.3f}")
# Out:
#    Silhouette Score: 0.423
#    Calinski-Harabasz Index: 19.6
#    Davies-Bouldin Index: 0.696

# %%
# Hierarchical Clustering for comparison
fig, axes = plt.subplots(figsize=(16, 6))

# Dendrogram
linkage_matrix = linkage(X_scaled, method='ward')
dendrogram(linkage_matrix, labels=province_names, ax=axes, leaf_rotation=90, leaf_font_size=8)
axes.set_title('Hierarchical Clustering Dendrogram (Ward Method)', fontweight='bold')
axes.set_xlabel('Province')
axes.set_ylabel('Distance')
axes.axhline(y=8, color='r', linestyle='--', linewidth=1.5, label='Cut at k=5')
axes.legend()

# Apply hierarchical clustering with k=5
hierarchical = AgglomerativeClustering(n_clusters=OPTIMAL_K, linkage='ward')
hier_labels = hierarchical.fit_predict(X_scaled)
features_df['Cluster_Hierarchical'] = hier_labels

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(16, 6))
# Compare cluster assignments
comparison = pd.crosstab(features_df['Cluster_KMeans'], features_df['Cluster_Hierarchical'])
sns.heatmap(comparison, annot=True, fmt='d', cmap='Blues', ax=axes)
axes.set_title('KMeans vs Hierarchical Cluster Assignment Comparison', fontweight='bold')
axes.set_xlabel('Hierarchical Cluster')
axes.set_ylabel('KMeans Cluster')

plt.tight_layout()
plt.show()

# %%
# Agreement rate
agreement = (kmeans_labels == hier_labels).mean()
print(f"\nAgreement between KMeans and Hierarchical: {agreement*100:.1f}%")
# Out:
# Agreement between KMeans and Hierarchical: 23.5%

# %%
# Calculate cluster means for key features
cluster_means = features_df.groupby('Cluster_KMeans')[numeric_features].mean()

# Display cluster profiles
cluster_profiles = pd.DataFrame()
for cluster in range(OPTIMAL_K):
    cluster_data = features_df[features_df['Cluster_KMeans'] == cluster]
    profile = {
        'Cluster': cluster,
        'N_Provinces': len(cluster_data),
        'Mean_Rainfall': cluster_data['Mean_Annual_Rainfall'].mean(),
        'Mean_Rainy_Days': cluster_data['Mean_Rainy_Days'].mean(),
        'Rainfall_Variability': cluster_data['Rainfall_Variability'].mean(),
        'Aridity_Index': cluster_data['Aridity_Index'].mean(),
        'Soil_Volcanic': cluster_data['Soil_Volcanic'].mean(),
        'Soil_Alluvial': cluster_data['Soil_Alluvial'].mean(),
        'Soil_Organic_Peat': cluster_data['Soil_Organic_Peat'].mean(),
        'Soil_Calcareous': cluster_data['Soil_Calcareous'].mean(),
        'Dominant_Region': cluster_data['Region'].mode().values[0],
        'Climate_Zone': cluster_data['Climate_Zone'].mode().values[0]
    }
    cluster_profiles = pd.concat([cluster_profiles, pd.DataFrame([profile])], ignore_index=True)

cluster_profiles.to_string(index=False)
# Out:
# ' Cluster  N_Provinces  Mean_Rainfall  Mean_Rainy_Days  Rainfall_Variability  Aridity_Index  Soil_Volcanic  Soil_Alluvial  Soil_Organic_Peat  Soil_Calcareous Dominant_Region   Climate_Zone\n       0            1    1748.420000       174.600000           1030.286311       0.699368       0.900000       0.800000           0.100000         0.400000       Java_Bali Tropical_Moist\n       1            3    3379.236667       194.050000            689.602350       1.351695       0.300000       0.700000           0.800000         0.200000         Sumatra   Tropical_Wet\n       2            6    2060.663333       165.108333            386.763434       0.824265       0.900000       0.800000           0.100000         0.400000       Java_Bali Tropical_Moist\n       3            2    1656.522500       117.650000            418.160978       0.662609       0.600000       0.400000           0.050000         0.800000   Nusa_Tenggara Tropical_Moist\n       4            6    2815.680000       215.772222            332.050242       1.126272       0.133333       0.516667           0.866667         0.133333      Kalimantan   Tropical_Wet\n       5            4    1413.412500       151.425000            380.440518       0.565365       0.400000       0.600000           0.300000         0.700000        Sulawesi Tropical_Moist\n       6            6    2477.971667       200.691667            924.629808       0.991189       0.300000       0.650000           0.750000         0.250000    Maluku_Papua   Tropical_Wet\n       7            4    1932.475000       172.350000            325.319548       0.772990       0.300000       0.700000           0.800000         0.200000         Sumatra Tropical_Moist\n       8            2    3045.780000       205.200000            641.663112       1.218312       0.400000       0.600000           0.300000         0.700000        Sulawesi   Tropical_Wet'

# %%
for cluster in range(OPTIMAL_K):
    cluster_data = features_df[features_df['Cluster_KMeans'] == cluster]
    print(f"Provinces: {', '.join(cluster_data['Provinsi'].values)}")
    print(f"\nClimate Characteristics:")
    print(f" Mean Annual Rainfall: {cluster_data['Mean_Annual_Rainfall'].mean():.0f} mm")
    print(f" Mean Rainy Days: {cluster_data['Mean_Rainy_Days'].mean():.0f} days/year")
    print(f" Rainfall Variability: {cluster_data['Rainfall_Variability'].mean():.0f} mm (std)")
    print(f" Aridity Index: {cluster_data['Aridity_Index'].mean():.2f}")
    print(f" Dominant Climate: {cluster_data['Climate_Zone'].mode().values[0]}")
    print(f"\nSoil Characteristics:")
    print(f" Volcanic Soil Index: {cluster_data['Soil_Volcanic'].mean():.2f}")
    print(f" Alluvial Soil Index: {cluster_data['Soil_Alluvial'].mean():.2f}")
    print(f" Organic/Peat Index: {cluster_data['Soil_Organic_Peat'].mean():.2f}")
    print(f" Calcareous Index: {cluster_data['Soil_Calcareous'].mean():.2f}")
    print(f" Dominant Region: {cluster_data['Region'].mode().values[0]}")
# Out:
# Provinces: Banten
#
# Climate Characteristics:
#  Mean Annual Rainfall: 1748 mm
#  Mean Rainy Days: 175 days/year
#  Rainfall Variability: 1030 mm (std)
#  Aridity Index: 0.70
#  Dominant Climate: Tropical_Moist
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.90
#  Alluvial Soil Index: 0.80
#  Organic/Peat Index: 0.10
#  Calcareous Index: 0.40
#  Dominant Region: Java_Bali
# Provinces: Sumatera Barat, Bengkulu, Kepulauan Riau
#
# Climate Characteristics:
#  Mean Annual Rainfall: 3379 mm
#  Mean Rainy Days: 194 days/year
#  Rainfall Variability: 690 mm (std)
#  Aridity Index: 1.35
#  Dominant Climate: Tropical_Wet
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.30
#  Alluvial Soil Index: 0.70
#  Organic/Peat Index: 0.80
#  Calcareous Index: 0.20
#  Dominant Region: Sumatra
# Provinces: DKI Jakarta, Jawa Barat, Jawa Tengah, DI Yogyakarta, Jawa Timur, Bali
#
# Climate Characteristics:
#  Mean Annual Rainfall: 2061 mm
#  Mean Rainy Days: 165 days/year
#  Rainfall Variability: 387 mm (std)
#  Aridity Index: 0.82
#  Dominant Climate: Tropical_Moist
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.90
#  Alluvial Soil Index: 0.80
#  Organic/Peat Index: 0.10
#  Calcareous Index: 0.40
#  Dominant Region: Java_Bali
# Provinces: Nusa Tenggara Barat, Nusa Tenggara Timur
#
# Climate Characteristics:
#  Mean Annual Rainfall: 1657 mm
#  Mean Rainy Days: 118 days/year
#  Rainfall Variability: 418 mm (std)
#  Aridity Index: 0.66
#  Dominant Climate: Tropical_Moist
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.60
#  Alluvial Soil Index: 0.40
#  Organic/Peat Index: 0.05
#  Calcareous Index: 0.80
#  Dominant Region: Nusa_Tenggara
# Provinces: Kalimantan Barat, Kalimantan Tengah, Kalimantan Selatan, Kalimantan Timur, Kalimantan Utara, Papua Barat
#
# Climate Characteristics:
#  Mean Annual Rainfall: 2816 mm
#  Mean Rainy Days: 216 days/year
#  Rainfall Variability: 332 mm (std)
#  Aridity Index: 1.13
#  Dominant Climate: Tropical_Wet
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.13
#  Alluvial Soil Index: 0.52
#  Organic/Peat Index: 0.87
#  Calcareous Index: 0.13
#  Dominant Region: Kalimantan
# Provinces: Sulawesi Tengah, Sulawesi Tenggara, Gorontalo, Sulawesi Barat
#
# Climate Characteristics:
#  Mean Annual Rainfall: 1413 mm
#  Mean Rainy Days: 151 days/year
#  Rainfall Variability: 380 mm (std)
#  Aridity Index: 0.57
#  Dominant Climate: Tropical_Moist
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.40
#  Alluvial Soil Index: 0.60
#  Organic/Peat Index: 0.30
#  Calcareous Index: 0.70
#  Dominant Region: Sulawesi
# Provinces: Sumatera Utara, Sumatera Selatan, Kepulauan Bangka Belitung, Maluku, Maluku Utara, Papua
#
# Climate Characteristics:
#  Mean Annual Rainfall: 2478 mm
#  Mean Rainy Days: 201 days/year
#  Rainfall Variability: 925 mm (std)
#  Aridity Index: 0.99
#  Dominant Climate: Tropical_Wet
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.30
#  Alluvial Soil Index: 0.65
#  Organic/Peat Index: 0.75
#  Calcareous Index: 0.25
#  Dominant Region: Maluku_Papua
# Provinces: Aceh, Riau, Jambi, Lampung
#
# Climate Characteristics:
#  Mean Annual Rainfall: 1932 mm
#  Mean Rainy Days: 172 days/year
#  Rainfall Variability: 325 mm (std)
#  Aridity Index: 0.77
#  Dominant Climate: Tropical_Moist
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.30
#  Alluvial Soil Index: 0.70
#  Organic/Peat Index: 0.80
#  Calcareous Index: 0.20
#  Dominant Region: Sumatra
# Provinces: Sulawesi Utara, Sulawesi Selatan
#
# Climate Characteristics:
#  Mean Annual Rainfall: 3046 mm
#  Mean Rainy Days: 205 days/year
#  Rainfall Variability: 642 mm (std)
#  Aridity Index: 1.22
#  Dominant Climate: Tropical_Wet
#
# Soil Characteristics:
#  Volcanic Soil Index: 0.40
#  Alluvial Soil Index: 0.60
#  Organic/Peat Index: 0.30
#  Calcareous Index: 0.70
#  Dominant Region: Sulawesi

# %%
# Visualize Cluster Characteristics
fig, axes = plt.subplots(figsize=(16, 10))

#Rainfall by Cluster
cluster_rainfall = features_df.groupby('Cluster_KMeans')['Mean_Annual_Rainfall'].mean()
colors = plt.cm.Set2(np.linspace(0, 1, OPTIMAL_K))
bars = axes.bar(cluster_rainfall.index, cluster_rainfall.values, color=colors)
axes.set_xlabel('Cluster')
axes.set_ylabel('Mean Annual Rainfall (mm)')
axes.set_title('Mean Rainfall by Cluster', fontweight='bold')
axes.axhline(y=features_df['Mean_Annual_Rainfall'].mean(), color='red', linestyle='--', label='National Mean')
axes.legend()

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(16, 10))

#Rainy Days by Cluster
cluster_rainy_days = features_df.groupby('Cluster_KMeans')['Mean_Rainy_Days'].mean()
bars = axes.bar(cluster_rainy_days.index, cluster_rainy_days.values, color=colors)
axes.set_xlabel('Cluster')
axes.set_ylabel('Mean Rainy Days')
axes.set_title('Mean Rainy Days by Cluster', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(16, 10))

#Soil Composition by Cluster
soil_features = ['Soil_Volcanic', 'Soil_Alluvial', 'Soil_Organic_Peat', 'Soil_Calcareous']
soil_means = features_df.groupby('Cluster_KMeans')[soil_features].mean()
x = np.arange(OPTIMAL_K)
width = 0.2
for i, soil in enumerate(soil_features):
    axes.bar(x + i*width, soil_means[soil], width, label=soil.replace('Soil_', ''))
axes.set_xlabel('Cluster')
axes.set_ylabel('Soil Index')
axes.set_title('Soil Composition by Cluster', fontweight='bold')
axes.set_xticks(x + width*1.5)
axes.set_xticklabels([f'Cluster {i}' for i in range(OPTIMAL_K)])
axes.legend(fontsize=8)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(16, 10))

#Aridity Index by Cluster
cluster_aridity = features_df.groupby('Cluster_KMeans')['Aridity_Index'].mean()
bars = axes.bar(cluster_aridity.index, cluster_aridity.values, color=colors)
axes.set_xlabel('Cluster')
axes.set_ylabel('Aridity Index')
axes.set_title('Aridity Index by Cluster', fontweight='bold')
axes.axhline(y=1.0, color='red', linestyle='--', label='Humid Threshold')
axes.legend()

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(16, 10))

#Provinces per Cluster
cluster_counts = features_df['Cluster_KMeans'].value_counts().sort_index()
axes.pie(cluster_counts.values, labels=[f'Cluster {i}\n({v} prov)' for i, v in cluster_counts.items()],
        autopct='%1.1f%%', colors=colors, startangle=90)
axes.set_title('Province Distribution by Cluster', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(16, 10))

#Rainfall Variability vs Mean Rainfall by Cluster
for cluster in range(OPTIMAL_K):
    cluster_data = features_df[features_df['Cluster_KMeans'] == cluster]
    axes.scatter(cluster_data['Mean_Annual_Rainfall'], cluster_data['Rainfall_Variability'],
                c=[colors[cluster]], label=f'Cluster {cluster}', s=100, alpha=0.7, edgecolors='black')
axes.set_xlabel('Mean Annual Rainfall (mm)')
axes.set_ylabel('Rainfall Variability (std)')
axes.set_title('Rainfall Characteristics by Cluster', fontweight='bold')
axes.legend()

plt.tight_layout()
plt.show()

# %%
# Definisi kelompok fungsional karbohidrat
carb_functional_groups = {
    'wetland_cereals': {
        'name': 'Wetland Cereals',
        'crops': ['Padi (Oryza sativa)'],
        'characteristics': 'Membutuhkan air tinggi, sawah tergenang',
        'water_requirement': 'Tinggi (>1500mm/tahun)',
        'soil_preference': ['Alluvial', 'Volcanic', 'Paddy soil'],
        'ideal_conditions': 'Lahan basah dengan irigasi baik'
    },
    'dryland_cereals': {
        'name': 'Dryland Cereals', 
        'crops': ['Jagung (Zea mays)', 'Sorgum (Sorghum bicolor)', 'Jewawut (Setaria italica)'],
        'characteristics': 'Tahan kering, adaptif terhadap variasi curah hujan',
        'water_requirement': 'Rendah-Sedang (600-1200mm/tahun)',
        'soil_preference': ['Volcanic', 'Calcareous', 'Sandy loam'],
        'ideal_conditions': 'Lahan kering dengan drainase baik'
    },
    'root_tubers_humid': {
        'name': 'Root & Tubers (Humid)',
        'crops': ['Singkong (Manihot esculenta)', 'Talas (Colocasia esculenta)', 
                  'Ubi Jalar (Ipomoea batatas)', 'Kentang (Solanum tuberosum)'],
        'characteristics': 'Fleksibel, adaptif berbagai kondisi lembab',
        'water_requirement': 'Sedang (1000-2000mm/tahun)',
        'soil_preference': ['Volcanic', 'Alluvial', 'Organic'],
        'ideal_conditions': 'Lahan lembab dengan tanah gembur'
    },
    'palms_starch_trees': {
        'name': 'Palms & Starch Trees',
        'crops': ['Sagu (Metroxylon sagu)', 'Aren (Arenga pinnata)', 'Enau'],
        'characteristics': 'Butuh air tinggi, habitat rawa dan lahan basah',
        'water_requirement': 'Sangat Tinggi (>2500mm/tahun)',
        'soil_preference': ['Organic/Peat', 'Swamp', 'Alluvial wetland'],
        'ideal_conditions': 'Lahan rawa, gambut, atau pesisir berair'
    },
    'drought_resilient_roots': {
        'name': 'Drought-Resilient Roots',
        'crops': ['Ganyong (Canna edulis)', 'Porang (Amorphophallus muelleri)', 
                  'Garut (Maranta arundinacea)', 'Suweg (Amorphophallus paeoniifolius)',
                  'Uwi/Gadung (Dioscorea spp.)'],
        'characteristics': 'Tahan kering, cocok untuk lahan marginal',
        'water_requirement': 'Rendah (<1000mm/tahun)',
        'soil_preference': ['Calcareous', 'Sandy', 'Marginal soil'],
        'ideal_conditions': 'Lahan marginal, kering, atau hutan'
    }
}

# %%
# Mapping cluster ke kelompok fungsional yang direkomendasikan
cluster_to_functional_groups = {
    0: {  # Moderate Rainfall Sumatra
        'primary': ['palms_starch_trees', 'wetland_cereals'],
        'diversification': ['root_tubers_humid'],
        'rationale': 'Tanah gambut tinggi cocok untuk sagu, curah hujan moderate mendukung padi sawah'
    },
    1: {  # Java-Bali Volcanic Zone  
        'primary': ['wetland_cereals', 'dryland_cereals'],
        'diversification': ['root_tubers_humid'],
        'rationale': 'Tanah vulkanik subur ideal untuk padi dan jagung, umbi sebagai diversifikasi'
    },
    2: {  # Humid Kalimantan-Papua Barat
        'primary': ['palms_starch_trees'],
        'diversification': ['root_tubers_humid'],
        'rationale': 'Curah hujan sangat tinggi dan tanah gambut dominan, sagu adalah pilihan utama'
    },
    3: {  # Wet Mixed Islands
        'primary': ['wetland_cereals', 'palms_starch_trees'],
        'diversification': ['root_tubers_humid', 'dryland_cereals'],
        'rationale': 'Kondisi campuran memungkinkan berbagai kelompok, fokus padi dan sagu'
    },
    4: {  # Dry Eastern Corridor
        'primary': ['dryland_cereals'],
        'diversification': ['drought_resilient_roots', 'root_tubers_humid'],
        'rationale': 'Curah hujan rendah, serealia tahan kering dan umbi marginal adalah pilihan tepat'
    }
}

# %%
# Update crop_mapping dengan kelompok fungsional
crop_mapping = {
    0: {
        'name': 'Moderate Rainfall Sumatra',
        'characteristics': 'Moderate rainfall (~1940mm), High peat/organic soil, Sumatra region',
        'functional_groups': {
            'primary': ['Palms & Starch Trees', 'Wetland Cereals'],
            'diversification': ['Root & Tubers (Humid)']
        },
        'primary_crops': ['Sago (Metroxylon sagu)', 'Rice (wetland varieties)'],
        'diversification_crops': ['Cassava (Manihot esculenta)', 'Taro (Colocasia esculenta)', 
                                   'Sweet Potato (Ipomoea batatas)'],
        'rationale': '''
        - High organic/peat soil index (0.8) indicates excellent sago potential (Palms & Starch Trees)
        - Moderate rainfall supports wetland rice cultivation (Wetland Cereals)
        - Cassava and taro thrive in tropical humid conditions (Root & Tubers - Humid)
        - Sweet potato provides food security during dry periods
        '''
    },
    1: {
        'name': 'Java-Bali Volcanic Zone',
        'characteristics': 'Moderate rainfall (~2014mm), High volcanic soil, Java-Bali region',
        'functional_groups': {
            'primary': ['Wetland Cereals', 'Dryland Cereals'],
            'diversification': ['Root & Tubers (Humid)']
        },
        'primary_crops': ['Rice (Oryza sativa)', 'Maize (Zea mays)'],
        'diversification_crops': ['Sweet Potato (Ipomoea batatas)', 'Cassava (Manihot esculenta)',
                                   'Potato (Solanum tuberosum) - highland', 'Taro (Colocasia esculenta)'],
        'rationale': '''
        - Highest volcanic soil index (0.9) indicates excellent fertility for all groups
        - High alluvial soil index (0.8) supports irrigated rice (Wetland Cereals)
        - Maize thrives in drier areas (Dryland Cereals)
        - Highland areas (>1000m) suitable for potato cultivation (Root & Tubers - Humid)
        - Traditional cultivation of tubers alongside rice
        '''
    },
    2: {
        'name': 'Humid Kalimantan-Papua Barat',
        'characteristics': 'High rainfall (~2883mm), Very high peat, Kalimantan-Papua region',
        'functional_groups': {
            'primary': ['Palms & Starch Trees'],
            'diversification': ['Root & Tubers (Humid)']
        },
        'primary_crops': ['Sago (Metroxylon sagu)', 'Swamp Rice varieties'],
        'diversification_crops': ['Taro (Colocasia esculenta)', 'Sago Palm products',
                                   'Wild yams (Dioscorea spp.)'],
        'rationale': '''
        - Highest organic/peat soil index (0.9) - ideal for sago (Palms & Starch Trees)
        - High rainfall (2883mm) with 212 rainy days supports wetland crops
        - Sago is indigenous and culturally significant in Papua
        - Taro thrives in waterlogged conditions (Root & Tubers - Humid)
        - Limited suitability for dry-land crops
        '''
    },
    3: {
        'name': 'Wet Mixed Islands',
        'characteristics': 'High rainfall (~2850mm), Mixed soil types, Diverse regions',
        'functional_groups': {
            'primary': ['Wetland Cereals', 'Palms & Starch Trees'],
            'diversification': ['Root & Tubers (Humid)', 'Dryland Cereals']
        },
        'primary_crops': ['Rice (wet and dry varieties)', 'Sago (in peat areas)'],
        'diversification_crops': ['Cassava (Manihot esculenta)', 'Sweet Potato (Ipomoea batatas)',
                                   'Taro (Colocasia esculenta)', 'Bananas (Musa spp.)'],
        'rationale': '''
        - High rainfall but moderate peat (0.55) allows diverse cultivation
        - Rice as Wetland Cereals, Sago as Palms & Starch Trees
        - Mixed regions from Sumatra islands to Eastern Indonesia
        - High variability suggests need for drought-tolerant alternatives
        - Cassava and sweet potato provide resilience (Root & Tubers - Humid)
        '''
    },
    4: {
        'name': 'Dry Eastern Corridor',
        'characteristics': 'Low rainfall (~1503mm), Calcareous soils, Nusa Tenggara-Sulawesi',
        'functional_groups': {
            'primary': ['Dryland Cereals'],
            'diversification': ['Drought-Resilient Roots', 'Root & Tubers (Humid)']
        },
        'primary_crops': ['Sorghum (Sorghum bicolor)', 'Millet (various)'],
        'diversification_crops': ['Cassava (drought-tolerant varieties)', 'Maize (dry varieties)',
                                   'Arrowroot (Maranta arundinacea)', 'Jewawut/Foxtail millet',
                                   'Porang (Amorphophallus muelleri)', 'Ganyong (Canna edulis)'],
        'rationale': '''
        - Lowest rainfall (1503mm) and aridity index (0.60) favor Dryland Cereals
        - Highest calcareous soil index (0.72) - alkaline conditions
        - Sorghum and millet are drought-adapted cereals (Dryland Cereals)
        - Traditional crops like jewawut (foxtail millet) are indigenous
        - Porang and ganyong excel in marginal land (Drought-Resilient Roots)
        - Cassava provides food security during dry seasons
        '''
    }
}

# %%
# Display functional groups overview
for group_id, group_info in carb_functional_groups.items():
    print(f"\n {group_info['name']}")
    print(f"   Crops: {', '.join(group_info['crops'])}")
    print(f"   Karakteristik: {group_info['characteristics']}")
    print(f"   Kebutuhan Air: {group_info['water_requirement']}")
    print(f"   Tipe Tanah: {', '.join(group_info['soil_preference'])}")
# Out:
#  Wetland Cereals
#    Crops: Padi (Oryza sativa)
#    Karakteristik: Membutuhkan air tinggi, sawah tergenang
#    Kebutuhan Air: Tinggi (>1500mm/tahun)
#    Tipe Tanah: Alluvial, Volcanic, Paddy soil
#
#  Dryland Cereals
#    Crops: Jagung (Zea mays), Sorgum (Sorghum bicolor), Jewawut (Setaria italica)
#    Karakteristik: Tahan kering, adaptif terhadap variasi curah hujan
#    Kebutuhan Air: Rendah-Sedang (600-1200mm/tahun)
#    Tipe Tanah: Volcanic, Calcareous, Sandy loam
#
#  Root & Tubers (Humid)
#    Crops: Singkong (Manihot esculenta), Talas (Colocasia esculenta), Ubi Jalar (Ipomoea batatas), Kentang (Solanum tuberosum)
#    Karakteristik: Fleksibel, adaptif berbagai kondisi lembab
#    Kebutuhan Air: Sedang (1000-2000mm/tahun)
#    Tipe Tanah: Volcanic, Alluvial, Organic
#
#  Palms & Starch Trees
#    Crops: Sagu (Metroxylon sagu), Aren (Arenga pinnata), Enau
#    Karakteristik: Butuh air tinggi, habitat rawa dan lahan basah
#    Kebutuhan Air: Sangat Tinggi (>2500mm/tahun)
#    Tipe Tanah: Organic/Peat, Swamp, Alluvial wetland
#
#  Drought-Resilient Roots
#    Crops: Ganyong (Canna edulis), Porang (Amorphophallus muelleri), Garut (Maranta arundinacea), Suweg (Amorphophallus paeoniifolius), Uwi/Gadung (Dioscorea spp.)
#    Karakteristik: Tahan kering, cocok untuk lahan marginal
#    Kebutuhan Air: Rendah (<1000mm/tahun)
#    Tipe Tanah: Calcareous, Sandy, Marginal soil

# %%
# Display crop mapping with functional groups
for cluster, info in crop_mapping.items():
    provinces = features_df[features_df['Cluster_KMeans'] == cluster]['Provinsi'].values
    print(f"CLUSTER {cluster}: {info['name']}")
    print(f"\nProvinces: {', '.join(provinces)}")
    print(f"Characteristics: {info['characteristics']}")
    
    print(f"\n KELOMPOK FUNGSIONAL:")
    print(f"   Primary: {', '.join(info['functional_groups']['primary'])}")
    print(f"   Diversifikasi: {', '.join(info['functional_groups']['diversification'])}")
    
    print(f"\n PRIMARY CROPS:")
    for crop in info['primary_crops']:
        print(f"  {crop}")
    print(f"\n DIVERSIFICATION CROPS:")
    for crop in info['diversification_crops']:
        print(f"  {crop}")
    print(f"\nRATIONALE:{info['rationale']}")
# Out:
# CLUSTER 0: Moderate Rainfall Sumatra
#
# Provinces: Banten
# Characteristics: Moderate rainfall (~1940mm), High peat/organic soil, Sumatra region
#
#  KELOMPOK FUNGSIONAL:
#    Primary: Palms & Starch Trees, Wetland Cereals
#    Diversifikasi: Root & Tubers (Humid)
#
#  PRIMARY CROPS:
#   Sago (Metroxylon sagu)
#   Rice (wetland varieties)
#
#  DIVERSIFICATION CROPS:
#   Cassava (Manihot esculenta)
#   Taro (Colocasia esculenta)
#   Sweet Potato (Ipomoea batatas)
#
# RATIONALE:
#         - High organic/peat soil index (0.8) indicates excellent sago potential (Palms & Starch Trees)
#         - Moderate rainfall supports wetland rice cultivation (Wetland Cereals)
#         - Cassava and taro thrive in tropical humid conditions (Root & Tubers - Humid)
#         - Sweet potato provides food security during dry periods
#
# CLUSTER 1: Java-Bali Volcanic Zone
#
# Provinces: Sumatera Barat, Bengkulu, Kepulauan Riau
# Characteristics: Moderate rainfall (~2014mm), High volcanic soil, Java-Bali region
#
#  KELOMPOK FUNGSIONAL:
#    Primary: Wetland Cereals, Dryland Cereals
#    Diversifikasi: Root & Tubers (Humid)
#
#  PRIMARY CROPS:
#   Rice (Oryza sativa)
#   Maize (Zea mays)
#
#  DIVERSIFICATION CROPS:
#   Sweet Potato (Ipomoea batatas)
#   Cassava (Manihot esculenta)
#   Potato (Solanum tuberosum) - highland
#   Taro (Colocasia esculenta)
#
# RATIONALE:
#         - Highest volcanic soil index (0.9) indicates excellent fertility for all groups
#         - High alluvial soil index (0.8) supports irrigated rice (Wetland Cereals)
#         - Maize thrives in drier areas (Dryland Cereals)
#         - Highland areas (>1000m) suitable for potato cultivation (Root & Tubers - Humid)
#         - Traditional cultivation of tubers alongside rice
#
# CLUSTER 2: Humid Kalimantan-Papua Barat
#
# Provinces: DKI Jakarta, Jawa Barat, Jawa Tengah, DI Yogyakarta, Jawa Timur, Bali
# Characteristics: High rainfall (~2883mm), Very high peat, Kalimantan-Papua region
#
#  KELOMPOK FUNGSIONAL:
#    Primary: Palms & Starch Trees
#    Diversifikasi: Root & Tubers (Humid)
#
#  PRIMARY CROPS:
#   Sago (Metroxylon sagu)
#   Swamp Rice varieties
#
#  DIVERSIFICATION CROPS:
#   Taro (Colocasia esculenta)
#   Sago Palm products
#   Wild yams (Dioscorea spp.)
#
# RATIONALE:
#         - Highest organic/peat soil index (0.9) - ideal for sago (Palms & Starch Trees)
#         - High rainfall (2883mm) with 212 rainy days supports wetland crops
#         - Sago is indigenous and culturally significant in Papua
#         - Taro thrives in waterlogged conditions (Root & Tubers - Humid)
#         - Limited suitability for dry-land crops
#
# CLUSTER 3: Wet Mixed Islands
#
# Provinces: Nusa Tenggara Barat, Nusa Tenggara Timur
# Characteristics: High rainfall (~2850mm), Mixed soil types, Diverse regions
#
#  KELOMPOK FUNGSIONAL:
#    Primary: Wetland Cereals, Palms & Starch Trees
#    Diversifikasi: Root & Tubers (Humid), Dryland Cereals
#
#  PRIMARY CROPS:
#   Rice (wet and dry varieties)
#   Sago (in peat areas)
#
#  DIVERSIFICATION CROPS:
#   Cassava (Manihot esculenta)
#   Sweet Potato (Ipomoea batatas)
#   Taro (Colocasia esculenta)
#   Bananas (Musa spp.)
#
# RATIONALE:
#         - High rainfall but moderate peat (0.55) allows diverse cultivation
#         - Rice as Wetland Cereals, Sago as Palms & Starch Trees
#         - Mixed regions from Sumatra islands to Eastern Indonesia
#         - High variability suggests need for drought-tolerant alternatives
#         - Cassava and sweet potato provide resilience (Root & Tubers - Humid)
#
# CLUSTER 4: Dry Eastern Corridor
#
# Provinces: Kalimantan Barat, Kalimantan Tengah, Kalimantan Selatan, Kalimantan Timur, Kalimantan Utara, Papua Barat
# Characteristics: Low rainfall (~1503mm), Calcareous soils, Nusa Tenggara-Sulawesi
#
#  KELOMPOK FUNGSIONAL:
#    Primary: Dryland Cereals
#    Diversifikasi: Drought-Resilient Roots, Root & Tubers (Humid)
#
#  PRIMARY CROPS:
#   Sorghum (Sorghum bicolor)
#   Millet (various)
#
#  DIVERSIFICATION CROPS:
#   Cassava (drought-tolerant varieties)
#   Maize (dry varieties)
#   Arrowroot (Maranta arundinacea)
#   Jewawut/Foxtail millet
#   Porang (Amorphophallus muelleri)
#   Ganyong (Canna edulis)
#
# RATIONALE:
#         - Lowest rainfall (1503mm) and aridity index (0.60) favor Dryland Cereals
#         - Highest calcareous soil index (0.72) - alkaline conditions
#         - Sorghum and millet are drought-adapted cereals (Dryland Cereals)
#         - Traditional crops like jewawut (foxtail millet) are indigenous
#         - Porang and ganyong excel in marginal land (Drought-Resilient Roots)
#         - Cassava provides food security during dry seasons

# %%
# Add cluster names and crop recommendations to the dataframe
cluster_names = {
    0: 'Moderate Rainfall Sumatra',
    1: 'Java-Bali Volcanic Zone',
    2: 'Humid Kalimantan-Papua Barat',
    3: 'Wet Mixed Islands',
    4: 'Dry Eastern Corridor'
}

# Mapping berdasarkan kelompok fungsional karbohidrat
primary_crops_map = {
    0: 'Sagu, Padi',                    # Palms & Starch Trees + Wetland Cereals
    1: 'Padi, Jagung',                  # Wetland Cereals + Dryland Cereals
    2: 'Sagu, Padi Rawa',               # Palms & Starch Trees
    3: 'Padi, Sagu',                    # Wetland Cereals + Palms & Starch Trees
    4: 'Sorgum, Jewawut'                # Dryland Cereals
}

diversification_map = {
    0: 'Aren, Talas, Singkong',                                # Palms (secondary) + Root & Tubers
    1: 'Kentang, Ubi Jalar, Talas',                            # Root & Tubers (Highland focus)
    2: 'Talas, Uwi, Keladi',                                   # Root & Tubers (Wetland tolerant)
    3: 'Jagung, Singkong, Ubi Jalar',                          # Dryland Cereals + Root & Tubers
    4: 'Porang, Ganyong, Garut'                                # Drought-Resilient Roots only
}

# Mapping kelompok fungsional utama per cluster
functional_group_primary_map = {
    0: 'Palms & Starch Trees, Wetland Cereals',
    1: 'Wetland Cereals, Dryland Cereals',
    2: 'Palms & Starch Trees',
    3: 'Wetland Cereals, Palms & Starch Trees',
    4: 'Dryland Cereals'
}

functional_group_diversification_map = {
    0: 'Palms (Aren), Root & Tubers',           # Gambut cocok untuk aren juga
    1: 'Root & Tubers (Highland)',              # Java punya highland untuk kentang
    2: 'Root & Tubers (Wetland)',               # Talas & uwi toleran genangan
    3: 'Dryland Cereals, Root & Tubers',        # Mixed conditions
    4: 'Drought-Resilient Roots'                # Khusus lahan marginal
}

# %%
features_df['Cluster_KMeans'] = features_df['Cluster_KMeans'].astype(int)

# %%
features_df['Cluster_Name'] = features_df['Cluster_KMeans'].map(cluster_names)
features_df['Primary_Crops'] = features_df['Cluster_KMeans'].map(primary_crops_map)
features_df['Diversification_Crops'] = features_df['Cluster_KMeans'].map(diversification_map)
features_df['Functional_Group_Primary'] = features_df['Cluster_KMeans'].map(functional_group_primary_map)
features_df['Functional_Group_Diversification'] = features_df['Cluster_KMeans'].map(functional_group_diversification_map)

# %%
final_output = features_df[['Provinsi', 'Region', 'Cluster_KMeans', 'Cluster_Name', 
                             'Mean_Annual_Rainfall', 'Climate_Zone', 
                             'Functional_Group_Primary', 'Primary_Crops', 
                             'Functional_Group_Diversification', 'Diversification_Crops']].copy()
final_output = final_output.sort_values('Cluster_KMeans')
final_output
# Out:
#                      Provinsi         Region  Cluster_KMeans  \
# 15                     Banten      Java_Bali               0
# 2              Sumatera Barat        Sumatra               1
# 9              Kepulauan Riau        Sumatra               1
# 6                    Bengkulu        Sumatra               1
# 10                DKI Jakarta      Java_Bali               2
# 11                 Jawa Barat      Java_Bali               2
# 12                Jawa Tengah      Java_Bali               2
# 13              DI Yogyakarta      Java_Bali               2
# 14                 Jawa Timur      Java_Bali               2
# 16                       Bali      Java_Bali               2
# 17        Nusa Tenggara Barat  Nusa_Tenggara               3
# 18        Nusa Tenggara Timur  Nusa_Tenggara               3
# 19           Kalimantan Barat     Kalimantan               4
# 22           Kalimantan Timur     Kalimantan               4
# 21         Kalimantan Selatan     Kalimantan               4
# 20          Kalimantan Tengah     Kalimantan               4
# 23           Kalimantan Utara     Kalimantan               4
# 32                Papua Barat   Maluku_Papua               4
# 29             Sulawesi Barat       Sulawesi               5
# 25            Sulawesi Tengah       Sulawesi               5
# 28                  Gorontalo       Sulawesi               5
# 27          Sulawesi Tenggara       Sulawesi               5
# 5            Sumatera Selatan        Sumatra               6
# 8   Kepulauan Bangka Belitung        Sumatra               6
# 30                     Maluku   Maluku_Papua               6
# 31               Maluku Utara   Maluku_Papua               6
# 33                      Papua   Maluku_Papua               6
# 1              Sumatera Utara        Sumatra               6
# 3                        Riau        Sumatra               7
# 0                        Aceh        Sumatra               7
# 4                       Jambi        Sumatra               7
# 7                     Lampung        Sumatra               7
# 24             Sulawesi Utara       Sulawesi               8
# 26           Sulawesi Selatan       Sulawesi               8
#
#                     Cluster_Name  Mean_Annual_Rainfall       Climate_Zone  \
# 15     Moderate Rainfall Sumatra              1748.420     Tropical_Moist
# 2        Java-Bali Volcanic Zone              3838.200   Equatorial_Humid
# 9        Java-Bali Volcanic Zone              3170.060       Tropical_Wet
# 6        Java-Bali Volcanic Zone              3129.450       Tropical_Wet
# 10  Humid Kalimantan-Papua Barat              2089.220     Tropical_Moist
# 11  Humid Kalimantan-Papua Barat              2313.660       Tropical_Wet
# 12  Humid Kalimantan-Papua Barat              2200.740       Tropical_Wet
# 13  Humid Kalimantan-Papua Barat              2135.880       Tropical_Wet
# 14  Humid Kalimantan-Papua Barat              1890.780     Tropical_Moist
# 16  Humid Kalimantan-Papua Barat              1733.700     Tropical_Moist
# 17             Wet Mixed Islands              1736.925     Tropical_Moist
# 18             Wet Mixed Islands              1576.120  Tropical_Seasonal
# 19          Dry Eastern Corridor              3020.960   Equatorial_Humid
# 22          Dry Eastern Corridor              2551.360       Tropical_Wet
# 21          Dry Eastern Corridor              2624.720       Tropical_Wet
# 20          Dry Eastern Corridor              2978.480       Tropical_Wet
# 23          Dry Eastern Corridor              2706.700       Tropical_Wet
# 32          Dry Eastern Corridor              3011.860   Equatorial_Humid
# 29                           NaN              1338.780  Tropical_Seasonal
# 25                           NaN               699.740          Semi_Arid
# 28                           NaN              1619.380     Tropical_Moist
# 27                           NaN              1995.750     Tropical_Moist
# 5                            NaN              2540.140       Tropical_Wet
# 8                            NaN              2197.580       Tropical_Wet
# 30                           NaN              3402.300   Equatorial_Humid
# 31                           NaN              2099.850       Tropical_Wet
# 33                           NaN              2434.380       Tropical_Wet
# 1                            NaN              2193.580       Tropical_Wet
# 3                            NaN              2412.340       Tropical_Wet
# 0                            NaN              1565.800     Tropical_Moist
# 4                            NaN              1947.700     Tropical_Moist
# 7                            NaN              1804.060     Tropical_Moist
# 24                           NaN              2881.160       Tropical_Wet
# 26                           NaN              3210.400       Tropical_Wet
#
#                  Functional_Group_Primary    Primary_Crops  \
# 15  Palms & Starch Trees, Wetland Cereals       Sagu, Padi
# 2        Wetland Cereals, Dryland Cereals     Padi, Jagung
# 9        Wetland Cereals, Dryland Cereals     Padi, Jagung
# 6        Wetland Cereals, Dryland Cereals     Padi, Jagung
# 10                   Palms & Starch Trees  Sagu, Padi Rawa
# 11                   Palms & Starch Trees  Sagu, Padi Rawa
# 12                   Palms & Starch Trees  Sagu, Padi Rawa
# 13                   Palms & Starch Trees  Sagu, Padi Rawa
# 14                   Palms & Starch Trees  Sagu, Padi Rawa
# 16                   Palms & Starch Trees  Sagu, Padi Rawa
# 17  Wetland Cereals, Palms & Starch Trees       Padi, Sagu
# 18  Wetland Cereals, Palms & Starch Trees       Padi, Sagu
# 19                        Dryland Cereals  Sorgum, Jewawut
# 22                        Dryland Cereals  Sorgum, Jewawut
# 21                        Dryland Cereals  Sorgum, Jewawut
# 20                        Dryland Cereals  Sorgum, Jewawut
# 23                        Dryland Cereals  Sorgum, Jewawut
# 32                        Dryland Cereals  Sorgum, Jewawut
# 29                                    NaN              NaN
# 25                                    NaN              NaN
# 28                                    NaN              NaN
# 27                                    NaN              NaN
# 5                                     NaN              NaN
# 8                                     NaN              NaN
# 30                                    NaN              NaN
# 31                                    NaN              NaN
# 33                                    NaN              NaN
# 1                                     NaN              NaN
# 3                                     NaN              NaN
# 0                                     NaN              NaN
# 4                                     NaN              NaN
# 7                                     NaN              NaN
# 24                                    NaN              NaN
# 26                                    NaN              NaN
#
#    Functional_Group_Diversification        Diversification_Crops
# 15      Palms (Aren), Root & Tubers        Aren, Talas, Singkong
# 2          Root & Tubers (Highland)    Kentang, Ubi Jalar, Talas
# 9          Root & Tubers (Highland)    Kentang, Ubi Jalar, Talas
# 6          Root & Tubers (Highland)    Kentang, Ubi Jalar, Talas
# 10          Root & Tubers (Wetland)           Talas, Uwi, Keladi
# 11          Root & Tubers (Wetland)           Talas, Uwi, Keladi
# 12          Root & Tubers (Wetland)           Talas, Uwi, Keladi
# 13          Root & Tubers (Wetland)           Talas, Uwi, Keladi
# 14          Root & Tubers (Wetland)           Talas, Uwi, Keladi
# 16          Root & Tubers (Wetland)           Talas, Uwi, Keladi
# 17   Dryland Cereals, Root & Tubers  Jagung, Singkong, Ubi Jalar
# 18   Dryland Cereals, Root & Tubers  Jagung, Singkong, Ubi Jalar
# 19          Drought-Resilient Roots       Porang, Ganyong, Garut
# 22          Drought-Resilient Roots       Porang, Ganyong, Garut
# 21          Drought-Resilient Roots       Porang, Ganyong, Garut
# 20          Drought-Resilient Roots       Porang, Ganyong, Garut
# 23          Drought-Resilient Roots       Porang, Ganyong, Garut
# 32          Drought-Resilient Roots       Porang, Ganyong, Garut
# 29                              NaN                          NaN
# 25                              NaN                          NaN
# 28                              NaN                          NaN
# 27                              NaN                          NaN
# 5                               NaN                          NaN
# 8                               NaN                          NaN
# 30                              NaN                          NaN
# 31                              NaN                          NaN
# 33                              NaN                          NaN
# 1                               NaN                          NaN
# 3                               NaN                          NaN
# 0                               NaN                          NaN
# 4                               NaN                          NaN
# 7                               NaN                          NaN
# 24                              NaN                          NaN
# 26                              NaN                          NaN

# %%
# Create comprehensive summary visualization
plt.figure(figsize=(18, 14))

# Define cluster colors
cluster_colors = {
    0: '#2ecc71',  # Green - Sumatra
    1: '#e74c3c',  # Red - Java-Bali
    2: '#3498db',  # Blue - Kalimantan
    3: '#f39c12',  # Orange - Mixed Islands
    4: '#9b59b6'   # Purple - Dry Eastern
}

#Cluster Summary Bar Chart
cluster_summary = features_df.groupby('Cluster_KMeans').agg({
    'Mean_Annual_Rainfall': 'mean',
    'Provinsi': 'count'
}).reset_index()

plt.bar(
    cluster_summary['Cluster_KMeans'],
    cluster_summary['Mean_Annual_Rainfall'],
    color=plt.cm.tab10(cluster_summary['Cluster_KMeans'])
)

plt.xlabel('Cluster')
plt.ylabel('Mean Annual Rainfall (mm)')
plt.title('Rainfall by Diversification Zone', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 14))
#Soil Composition Heatmap
soil_cols = ['Soil_Volcanic', 'Soil_Alluvial', 'Soil_Organic_Peat', 'Soil_Calcareous']
soil_matrix = features_df.groupby('Cluster_KMeans')[soil_cols].mean()
soil_matrix.columns = ['Volcanic', 'Alluvial', 'Organic/Peat', 'Calcareous']

sns.heatmap(
    soil_matrix,
    annot=True,
    fmt='.2f',
    cmap='YlOrRd'
)

plt.title('Soil Composition by Cluster', fontweight='bold')
plt.xlabel('Soil Type')
plt.ylabel('Cluster')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='polar')

categories = ['Rainfall', 'Rainy Days', 'Volcanic', 'Alluvial', 'Peat', 'Aridity']
N = len(categories)
angles = np.linspace(0, 2*np.pi, N, endpoint=False).tolist()
angles += angles[:1]

colors = plt.cm.tab10(np.arange(OPTIMAL_K))

for cluster in range(OPTIMAL_K):
    cluster_data = features_df[features_df['Cluster_KMeans'] == cluster]
    values = [
        cluster_data['Mean_Annual_Rainfall'].mean() / 4000,
        cluster_data['Mean_Rainy_Days'].mean() / 250,
        cluster_data['Soil_Volcanic'].mean(),
        cluster_data['Soil_Alluvial'].mean(),
        cluster_data['Soil_Organic_Peat'].mean(),
        cluster_data['Aridity_Index'].mean()
    ]
    values += values[:1]

    ax.plot(angles, values, linewidth=2, color=colors[cluster],
            label=f'Cluster {cluster}')
    ax.fill(angles, values, alpha=0.1, color=colors[cluster])

ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)
ax.set_title('Cluster Profiles (Normalized)', fontweight='bold')
ax.legend(bbox_to_anchor=(1.3, 1))

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Daftar kelompok fungsional karbohidrat
functional_groups = [
    'Wetland Cereals',
    'Dryland Cereals',
    'Root & Tubers (Humid)',
    'Palms & Starch Trees',
    'Drought-Resilient Roots'
]

# Ambil mapping kelompok fungsional dari crop_mapping
cluster_names_list = [crop_mapping[i]['name'] for i in crop_mapping]
cluster_fg_matrix = []
for i in crop_mapping:
    fg_present = []
    fg_dict = crop_mapping[i].get('functional_groups', {})
    # Gabungkan primary & diversification
    fg_all = fg_dict.get('primary', []) + fg_dict.get('diversification', [])
    for fg in functional_groups:
        fg_present.append(1 if fg in fg_all else 0)
    cluster_fg_matrix.append(fg_present)

fg_df = pd.DataFrame(cluster_fg_matrix, columns=functional_groups, index=cluster_names_list)

sns.heatmap(
    fg_df,
    annot=True,
    cmap='YlGn',
    cbar_kws={'label': 'Ada (1) / Tidak (0)'},
    linewidths=0.5,
    linecolor='white'
)
plt.title('Kelompok Fungsional Karbohidrat per Cluster', fontweight='bold', fontsize=12)
plt.yticks(rotation=0, fontsize=9)
plt.xticks(rotation=30, ha='right', fontsize=9)
plt.xlabel('Kelompok Fungsional')
plt.ylabel('Cluster')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

region_cluster = pd.crosstab(
    features_df['Region'],
    features_df['Cluster_Name']
)

region_cluster.plot(
    kind='bar',
    stacked=True,
    edgecolor='white',
    colormap='tab10'
)

plt.xlabel('Geographic Region')
plt.ylabel('Number of Provinces')
plt.title('Cluster Distribution by Region', fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.legend(title='Cluster', fontsize=8)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 7))

colors = plt.cm.tab10(range(OPTIMAL_K))

for cluster in range(OPTIMAL_K):
    cluster_data = features_df[features_df['Cluster_KMeans'] == cluster]
    plt.scatter(
        cluster_data['Mean_Annual_Rainfall'],
        cluster_data['Aridity_Index'],
        s=100,
        alpha=0.7,
        edgecolors='black',
        color=colors[cluster],
        label=cluster_names.get(cluster, f'Cluster {cluster}')
    )

plt.xlabel('Mean Annual Rainfall (mm)')
plt.ylabel('Aridity Index')
plt.title('Climate Space by Cluster', fontweight='bold')
plt.axhline(y=1.0, color='gray', linestyle='--', alpha=0.5)
plt.text(3500, 1.02, 'Humid Threshold', fontsize=8, color='gray')
plt.legend(fontsize=8)

plt.tight_layout()
plt.show()

# %%
# Prepare export dataframe
export_df = features_df[[
    'Provinsi', 'Region', 'Cluster_KMeans', 'Cluster_Name',
    'Mean_Annual_Rainfall', 'Mean_Rainy_Days', 'Rainfall_Variability',
    'Aridity_Index', 'Climate_Zone',
    'Soil_Volcanic', 'Soil_Alluvial', 'Soil_Organic_Peat', 'Soil_Calcareous',
    'Soil_Quality_Index',
    'Primary_Crops', 'Diversification_Crops'
]].copy()

export_df = export_df.sort_values(['Cluster_KMeans', 'Provinsi'])
export_df.to_csv('hasil_clustering_diversifikasi.csv', index=False, encoding='utf-8')

# %%
summary_table = pd.DataFrame({
    'Cluster': [f'C{i}' for i in range(5)],
    'Name': list(cluster_names.values()),
    'Provinces': [4, 7, 6, 11, 6],
    'Avg_Rainfall_mm': [1940, 2014, 2883, 2850, 1503],
    'Functional_Group_Primary': [
        'Palms & Starch Trees, Wetland Cereals',
        'Wetland Cereals, Dryland Cereals', 
        'Palms & Starch Trees',
        'Wetland Cereals, Palms & Starch Trees',
        'Dryland Cereals'
    ],
    'Primary_Crop': ['Sagu, Padi', 'Padi, Jagung', 'Sagu, Padi Rawa', 'Padi, Sagu', 'Sorgum, Jewawut'],
    'Functional_Group_Diversification': [
        'Palms (Aren), Root & Tubers',      # C0: Gambut cocok untuk aren juga
        'Root & Tubers (Highland)',          # C1: Java punya dataran tinggi untuk kentang
        'Root & Tubers (Wetland)',           # C2: Talas & uwi toleran genangan
        'Dryland Cereals, Root & Tubers',    # C3: Mixed - jagung + singkong
        'Drought-Resilient Roots'            # C4: Khusus marginal land
    ],
    'Key_Diversification': ['Aren, Talas, Singkong', 'Kentang, Ubi Jalar, Talas', 'Talas, Uwi, Keladi', 'Jagung, Singkong, Ubi', 'Porang, Ganyong, Garut']
})
print(summary_table.to_string(index=False))
# Out:
# Cluster                         Name  Provinces  Avg_Rainfall_mm              Functional_Group_Primary    Primary_Crop Functional_Group_Diversification       Key_Diversification
#      C0    Moderate Rainfall Sumatra          4             1940 Palms & Starch Trees, Wetland Cereals      Sagu, Padi      Palms (Aren), Root & Tubers     Aren, Talas, Singkong
#      C1      Java-Bali Volcanic Zone          7             2014      Wetland Cereals, Dryland Cereals    Padi, Jagung         Root & Tubers (Highland) Kentang, Ubi Jalar, Talas
#      C2 Humid Kalimantan-Papua Barat          6             2883                  Palms & Starch Trees Sagu, Padi Rawa          Root & Tubers (Wetland)        Talas, Uwi, Keladi
#      C3            Wet Mixed Islands         11             2850 Wetland Cereals, Palms & Starch Trees      Padi, Sagu   Dryland Cereals, Root & Tubers     Jagung, Singkong, Ubi
#      C4         Dry Eastern Corridor          6             1503                       Dryland Cereals Sorgum, Jewawut          Drought-Resilient Roots    Porang, Ganyong, Garut

# %%
fig, ax = plt.subplots(figsize=(16, 10))

# Create colormap for agricultural soil classes
agri_soil_colors = {
    'Alluvial': '#3498db',
    'Volcanic': '#e74c3c',
    'Organic_Peat': '#27ae60',
    'Lateritic_Weathered': '#f39c12',
    'Calcareous': '#9b59b6',
    'Sandy': '#f1c40f',
    'Clayey_Hydromorphic': '#1abc9c',
    'Rocky_Shallow': '#95a5a6',
    'Cambisol': '#e67e22',
    'Other': '#7f8c8d'
}

# Plot soil map
soil_gdf.plot(column='Agri_Soil_Class', ax=ax, legend=True, 
              cmap='tab10', edgecolor='none', alpha=0.8,
              legend_kwds={'loc': 'lower left', 'fontsize': 8, 'title': 'Soil Type'})

ax.set_title('Agricultural Soil Classification Map of Indonesia', fontweight='bold', fontsize=14)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_xlim(95, 141)
ax.set_ylim(-11, 6)

# Add text annotation
ax.text(96, -5, 'Data: FAO Soil Classification\nProcessed for Agricultural Suitability', 
        fontsize=8, style='italic', verticalalignment='bottom')

plt.tight_layout()
plt.show()
